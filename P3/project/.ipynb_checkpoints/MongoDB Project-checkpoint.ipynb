# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
"""
Your task is to use the iterative parsing to process the map file and
find out not only what tags are there, but also how many, to get the
feeling on how much of which data you can expect to have in the map.
Fill out the count_tags function. It should return a dictionary with the
tag name as the key and number of times this tag can be encountered in
the map as value.

Note that your code will be tested with a different data file than the 'example.osm'
"""
import xml.etree.cElementTree as ET
import pprint


def count_tags(filename):
    d = {}
    for event, elem in ET.iterparse(filename):
        # print elem.tag
        if elem.tag in d:
            d[elem.tag] += 1
        else:
            d[elem.tag] = 1
    # print pprint.pprint(d)
    return d


def test():
    osm_file = open("/Users/jpowell/Downloads/data/miami_florida.osm", "r")

    tags = count_tags(osm_file)
    pprint.pprint(tags)

if __name__ == "__main__":
    test()
# Out:
# {'bounds': 1,
#  'member': 42426,
#  'nd': 1807642,
#  'node': 1516787,
#  'osm': 1,
#  'relation': 1523,
#  'tag': 1477841,
#  'way': 198244}

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.cElementTree as ET
import pprint
import re
"""
Your task is to explore the data a bit more.
Before you process the data and add it into MongoDB, you should
check the "k" value for each "<tag>" and see if they can be valid keys in MongoDB,
as well as see if there are any other potential problems.

We have provided you with 3 regular expressions to check for certain patterns
in the tags. As we saw in the quiz earlier, we would like to change the data model
and expand the "addr:street" type of keys to a dictionary like this:
{"address": {"street": "Some value"}}
So, we have to see if we have such tags, and if we have any tags with problematic characters.
Please complete the function 'key_type'.
"""


lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    if element.tag == "tag":
        for tag in element.iter("tag"):
            value = tag.attrib['k'] 
            if lower.search(value):
                keys['lower'] += 1
#                 print 'lower'
#                 print value
            elif lower_colon.search(value):
                keys['lower_colon'] += 1
#                 print 'lower_colon'
#                 print value
            elif problemchars.search(value):
                keys['problemchars'] += 1
                print 'problemchars'
                print value
            else:
                keys['other'] += 1
#                 print 'other'
#                 print value

    return keys


def count_tags(element, dictionary):
    if element.tag == "tag":
        for tag in element.iter("tag"):
            value = tag.attrib["k"]
            # print elem.tag
            if value in dictionary:
                dictionary[value] += 1
            else:
                dictionary[value] = 1
        # print pprint.pprint(d)
    return dictionary


def process_map(filename):
    d = {}
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)
        d = count_tags(element, d)

    return keys, d


def test():
    # You can use another testfile 'map.osm' to look at your solution
    # Note that the assertions will be incorrect then.
    osm_file = open("/Users/jpowell/Downloads/data/miami_florida.osm", "r")

    keys = process_map(osm_file)
    pprint.pprint(keys)
    

if __name__ == "__main__":
    test()
# Out:
# problemchars
# Gourmet Foods
# problemchars
# Moving From
# ({'lower': 602295, 'lower_colon': 829057, 'other': 46487, 'problemchars': 2},
#  {'Company': 1,
#   'FCC_ASR_Reg': 2,
#   'FIXME': 1528,
#   'FIXME:aeroway': 1,
#   'FIXME:amenity': 10,
#   'FIXME:building': 2,
#   'FIXME:construction': 7,
#   'FIXME:cycleway': 23,
#   'FIXME:depth': 4,
#   'FIXME:hgv': 39,
#   'FIXME:highway': 6,
#   'FIXME:lanes': 9,
#   'FIXME:lcn_ref': 1,
#   'FIXME:maxspeed': 193,
#   'FIXME:name': 38,
#   'FIXME:old_ref:1945': 40,
#   'FIXME:old_ref:pre_1945': 4,
#   'Gourmet Foods': 1,
#   'HFCS': 11196,
#   'ISO3166-1': 1,
#   'ISO3166-1:alpha2': 1,
#   'ISO3166-1:alpha3': 1,
#   'ISO3166-1:numeric': 1,
#   'ISO3166-2': 1,
#   'Moving From': 1,
#   'NHD:ComID': 103,
#   'NHD:FCode': 103,
#   'NHD:FDate': 12,
#   'NHD:FTYPE': 12,
#   'NHD:FType': 91,
#   'NHD:Permanent_': 12,
#   'NHD:RESOLUTION': 103,
#   'NHD:ReachCode': 88,
#   'NHD:way_id': 91,
#   'NHS': 2473,
#   'PKSCHOOL': 1,
#   'abandoned:building': 1,
#   'access': 4409,
#   'addr:city': 20011,
#   'addr:country': 18304,
#   'addr:floor': 1,
#   'addr:full': 18244,
#   'addr:housename': 82,
#   'addr:housenumber': 20311,
#   'addr:interpolation': 17,
#   'addr:postcode': 19615,
#   'addr:province': 2,
#   'addr:source': 2,
#   'addr:state': 20683,
#   'addr:street': 20445,
#   'addr:suburb': 17254,
#   'addr:suite': 1,
#   'addr:unit': 6,
#   'address': 1,
#   'admin_level': 441,
#   'aerialway': 3,
#   'aerodrome': 1,
#   'aeroway': 1741,
#   'alt_name': 857,
#   'alt_name:vi': 1,
#   'alt_name_1': 1,
#   'alt_ref': 12,
#   'amenity': 9135,
#   'amenity_1': 1,
#   'area': 894,
#   'area:highway': 1,
#   'artist_name': 7,
#   'artwork_type': 9,
#   'atm': 122,
#   'attraction': 84,
#   'attribution': 93,
#   'backrest': 38,
#   'bar': 1,
#   'barrier': 1948,
#   'beach': 3,
#   'bench': 18,
#   'bicycle': 3879,
#   'bicycle:lanes': 1,
#   'bicycle_parking': 16,
#   'bin': 2,
#   'board_type': 1,
#   'boat': 69,
#   'border_type': 352,
#   'boundary': 640,
#   'boundary_type': 3,
#   'brand': 48,
#   'bridge': 3406,
#   'bridge:movable': 2,
#   'bridge:structure': 3,
#   'building': 34839,
#   'building:colour': 37,
#   'building:height': 1,
#   'building:levels': 406,
#   'building:material': 12,
#   'building:part': 56,
#   'building:type': 2,
#   'building:use': 18,
#   'building_1': 1,
#   'bus': 65,
#   'button_operated': 1,
#   'cables': 536,
#   'capacity': 38,
#   'capacity:disabled': 5,
#   'car_wash': 2,
#   'census:population': 93,
#   'centre_turn_lane': 126,
#   'circuits': 435,
#   'clothes': 1,
#   'collection_times': 2,
#   'colour': 168,
#   'communication:mobile_phone': 1,
#   'constr': 1,
#   'construction': 276,
#   'construction:lanes': 43,
#   'contact:email': 2,
#   'contact:facebook': 1,
#   'contact:google_plus': 1,
#   'contact:phone': 9,
#   'contact:twitter': 1,
#   'contact:website': 5,
#   'county_id': 1,
#   'courts': 1,
#   'covered': 137,
#   'craft': 4,
#   'created_by': 296,
#   'crossing': 930,
#   'crossing:barrier': 4,
#   'crossing:bell': 2,
#   'crossing:light': 2,
#   'crossing_ref': 6,
#   'cuisine': 530,
#   'cuisine_1': 1,
#   'cutting': 40,
#   'cycle_network': 10,
#   'cyclerating': 2,
#   'cycleway': 1737,
#   'cycleway:left': 6,
#   'cycleway:right': 54,
#   'deep_draft': 33,
#   'delivery': 12,
#   'demolished:highway': 32,
#   'demolished:man_made': 1,
#   'demolished:power': 1,
#   'denomination': 275,
#   'denotation': 65,
#   'depth': 40,
#   'description': 80,
#   'description:en': 1,
#   'design': 129,
#   'designation': 18,
#   'destination': 308,
#   'destination:forward': 4,
#   'destination:lanes': 10,
#   'destination:ref': 174,
#   'diet': 1,
#   'direction': 44,
#   'direction_east': 4,
#   'direction_north': 10,
#   'direction_south': 2,
#   'direction_west': 7,
#   'dispensing': 13,
#   'dist:blue': 28,
#   'dist:gold': 27,
#   'dist:red': 28,
#   'dist:white': 28,
#   'disused': 33,
#   'disused:aeroway': 1,
#   'disused:amenity': 1,
#   'disused:highway': 12,
#   'disused:leisure': 3,
#   'dog': 2,
#   'drinking_water': 8,
#   'drinking_water:legal': 2,
#   'drive_in': 2,
#   'drive_through': 26,
#   'ele': 5576,
#   'electrified': 388,
#   'email': 12,
#   'embankment': 438,
#   'emergency': 113,
#   'end_date': 1,
#   'entrance': 116,
#   'est_width': 8,
#   'except': 2,
#   'exit_to': 108,
#   'faa': 2,
#   'fax': 11,
#   'fcc_reg': 1,
#   'fdot:fihs': 2119,
#   'fdot:ref': 3,
#   'fdot:sis': 2496,
#   'fee': 154,
#   'female': 2,
#   'fence': 1,
#   'fence_type': 50,
#   'fenced': 1,
#   'finely_mown': 35,
#   'fire_hydrant:type': 32,
#   'fireplace': 5,
#   'fixme': 150,
#   'flag': 1,
#   'food': 2,
#   'foot': 3715,
#   'footway': 566,
#   'frequency': 838,
#   'from': 8,
#   'fuel:diesel': 2,
#   'fuel:octane_91': 1,
#   'gauge': 313,
#   'generator:output:electricity': 1,
#   'generator:source': 2,
#   'gluten_free': 1,
#   'gnis:Class': 489,
#   'gnis:County': 489,
#   'gnis:County_num': 489,
#   'gnis:ST_alpha': 489,
#   'gnis:ST_num': 489,
#   'gnis:county_id': 3416,
#   'gnis:county_name': 1645,
#   'gnis:created': 3532,
#   'gnis:edited': 23,
#   'gnis:feature_id': 5137,
#   'gnis:feature_type': 117,
#   'gnis:id': 489,
#   'gnis:import_uuid': 1524,
#   'gnis:reviewed': 1522,
#   'gnis:state_id': 3416,
#   'golf': 1516,
#   'golf:course': 39,
#   'golf:designer': 4,
#   'golf:par': 39,
#   'golf_cart': 9,
#   'gtfs_id': 8342,
#   'gtfs_route_color': 106,
#   'gtfs_route_id': 106,
#   'gtfs_route_long_name': 106,
#   'gtfs_route_short_name': 106,
#   'gtfs_route_text_color': 106,
#   'gtfs_route_type': 106,
#   'guidepost': 6,
#   'handicap': 74,
#   'handrail': 1,
#   'harbour': 1,
#   'harbour:electricity': 1,
#   'harbour:fuel_station': 1,
#   'harbour:laundrette': 1,
#   'harbour:showers': 1,
#   'harbour:water_tap': 1,
#   'hazard:bicycle': 31,
#   'height': 104,
#   'height_agl_m': 2,
#   'heritage': 1,
#   'heritage:operator': 1,
#   'hgv': 6781,
#   'hgv:national_network': 441,
#   'hgv:tandem': 39,
#   'highway': 161302,
#   'highway:demolished': 2,
#   'historic': 31,
#   'history': 11,
#   'hoops': 14,
#   'horizontal_bar': 1,
#   'horse': 3273,
#   'hotel': 1,
#   'hov': 522,
#   'ht_agl_m': 2,
#   'iata': 10,
#   'icao': 8,
#   'image': 26,
#   'import_uuid': 491,
#   'incline': 15,
#   'incorporation_type': 197,
#   'indoor': 3,
#   'information': 98,
#   'intermittent': 118,
#   'internet_access': 28,
#   'internet_access:fee': 5,
#   'is_in': 688,
#   'is_in:city': 1,
#   'is_in:continent': 2,
#   'is_in:country': 187,
#   'is_in:country_code': 187,
#   'is_in:iso_3166_2': 185,
#   'is_in:state': 297,
#   'is_in:state_code': 185,
#   'is_in:theme_park': 20,
#   'iucn_level': 1,
#   'junction': 530,
#   'kayak': 2,
#   'landuse': 2780,
#   'lanes': 16621,
#   'lanes:backward': 6,
#   'lanes:forward': 9,
#   'layer': 2153,
#   'lcn': 175,
#   'lcn_ref': 66,
#   'leaf_type': 60,
#   'leisure': 4403,
#   'length': 9,
#   'length_ft': 3,
#   'length_m': 3,
#   'length_unit': 1,
#   'level': 15,
#   'light_rail': 1,
#   'line': 37,
#   'lit': 215,
#   'loc_name': 1,
#   'location': 274,
#   'male': 2,
#   'man_made': 1777,
#   'map_size': 2,
#   'maritime': 2,
#   'material': 171,
#   'materialt': 1,
#   'maxheight': 10,
#   'maxspeed': 7000,
#   'maxspeed:backward': 171,
#   'maxspeed:forward': 171,
#   'maxstay': 1,
#   'maze': 1,
#   'microbrewery': 4,
#   'monitoring_station': 1,
#   'mooring': 1,
#   'motor_vehicle': 275,
#   'motorcar': 9,
#   'motorcycle': 6,
#   'mown': 39,
#   'mtb:scale': 2,
#   'mtb:scale:imba': 3,
#   'name': 116840,
#   'name:ab': 1,
#   'name:ace': 1,
#   'name:af': 1,
#   'name:als': 1,
#   'name:am': 1,
#   'name:an': 1,
#   'name:ang': 1,
#   'name:ar': 2,
#   'name:arc': 1,
#   'name:arz': 1,
#   'name:as': 1,
#   'name:ast': 1,
#   'name:av': 1,
#   'name:ay': 1,
#   'name:az': 1,
#   'name:ba': 1,
#   'name:bar': 1,
#   'name:bat-smg': 1,
#   'name:bcl': 1,
#   'name:be': 2,
#   'name:be-x-old': 1,
#   'name:bg': 1,
#   'name:bi': 1,
#   'name:bm': 1,
#   'name:bn': 1,
#   'name:bo': 1,
#   'name:botanical': 19,
#   'name:bpy': 1,
#   'name:br': 1,
#   'name:bs': 1,
#   'name:bxr': 1,
#   'name:ca': 1,
#   'name:cbk-zam': 1,
#   'name:cdo': 1,
#   'name:ce': 1,
#   'name:ceb': 1,
#   'name:chr': 1,
#   'name:chy': 1,
#   'name:ckb': 1,
#   'name:co': 1,
#   'name:crh': 1,
#   'name:cs': 1,
#   'name:csb': 1,
#   'name:cu': 1,
#   'name:cv': 1,
#   'name:cy': 1,
#   'name:da': 1,
#   'name:de': 11,
#   'name:diq': 1,
#   'name:dsb': 1,
#   'name:dv': 1,
#   'name:dz': 1,
#   'name:ee': 1,
#   'name:el': 2,
#   'name:eml': 1,
#   'name:en': 14,
#   'name:eo': 2,
#   'name:es': 4,
#   'name:et': 1,
#   'name:eu': 1,
#   'name:ext': 1,
#   'name:fa': 2,
#   'name:ff': 1,
#   'name:fi': 1,
#   'name:fiu-vro': 1,
#   'name:fo': 1,
#   'name:fr': 7,
#   'name:frp': 1,
#   'name:frr': 1,
#   'name:fur': 1,
#   'name:fy': 1,
#   'name:ga': 1,
#   'name:gag': 1,
#   'name:gan': 1,
#   'name:gd': 1,
#   'name:gl': 1,
#   'name:glk': 1,
#   'name:gn': 1,
#   'name:gu': 1,
#   'name:gv': 1,
#   'name:ha': 1,
#   'name:hak': 1,
#   'name:haw': 2,
#   'name:he': 2,
#   'name:hi': 1,
#   'name:hif': 1,
#   'name:hr': 1,
#   'name:hsb': 1,
#   'name:ht': 1,
#   'name:hu': 1,
#   'name:hy': 2,
#   'name:ia': 1,
#   'name:id': 1,
#   'name:ie': 1,
#   'name:ig': 1,
#   'name:ik': 1,
#   'name:ilo': 1,
#   'name:io': 1,
#   'name:is': 2,
#   'name:it': 3,
#   'name:iu': 1,
#   'name:ja': 2,
#   'name:jbo': 1,
#   'name:jv': 1,
#   'name:ka': 2,
#   'name:kaa': 1,
#   'name:kab': 1,
#   'name:kbd': 1,
#   'name:ki': 1,
#   'name:kk': 1,
#   'name:kl': 1,
#   'name:km': 1,
#   'name:kn': 1,
#   'name:ko': 2,
#   'name:koi': 1,
#   'name:krc': 1,
#   'name:ks': 1,
#   'name:ksh': 1,
#   'name:ku': 1,
#   'name:kv': 1,
#   'name:kw': 1,
#   'name:ky': 1,
#   'name:la': 2,
#   'name:lad': 1,
#   'name:lb': 1,
#   'name:lbe': 1,
#   'name:lez': 1,
#   'name:lg': 1,
#   'name:li': 1,
#   'name:lij': 1,
#   'name:lmo': 1,
#   'name:ln': 1,
#   'name:lo': 1,
#   'name:lt': 3,
#   'name:ltg': 1,
#   'name:lv': 1,
#   'name:map-bms': 1,
#   'name:mdf': 1,
#   'name:mg': 1,
#   'name:mhr': 1,
#   'name:mi': 1,
#   'name:min': 1,
#   'name:mk': 1,
#   'name:ml': 1,
#   'name:mn': 1,
#   'name:mr': 1,
#   'name:mrj': 1,
#   'name:ms': 1,
#   'name:mt': 1,
#   'name:mwl': 1,
#   'name:my': 1,
#   'name:myv': 1,
#   'name:mzn': 1,
#   'name:na': 1,
#   'name:nah': 1,
#   'name:nap': 1,
#   'name:nds': 1,
#   'name:nds-nl': 1,
#   'name:ne': 1,
#   'name:new': 1,
#   'name:nl': 2,
#   'name:nn': 1,
#   'name:no': 1,
#   'name:nov': 1,
#   'name:nrm': 1,
#   'name:nso': 1,
#   'name:nv': 2,
#   'name:oc': 1,
#   'name:om': 1,
#   'name:or': 1,
#   'name:os': 1,
#   'name:pa': 1,
#   'name:pag': 1,
#   'name:pam': 1,
#   'name:pap': 1,
#   'name:pcd': 1,
#   'name:pdc': 1,
#   'name:pfl': 1,
#   'name:pih': 1,
#   'name:pl': 2,
#   'name:pms': 1,
#   'name:pnb': 1,
#   'name:ps': 1,
#   'name:pt': 4,
#   'name:qu': 2,
#   'name:rm': 1,
#   'name:rn': 1,
#   'name:ro': 2,
#   'name:roa-tara': 1,
#   'name:ru': 20,
#   'name:rue': 1,
#   'name:rw': 1,
#   'name:sa': 1,
#   'name:sah': 1,
#   'name:sc': 1,
#   'name:scn': 1,
#   'name:sco': 1,
#   'name:sd': 1,
#   'name:se': 1,
#   'name:sg': 1,
#   'name:sh': 1,
#   'name:si': 1,
#   'name:simple': 1,
#   'name:sk': 1,
#   'name:sl': 1,
#   'name:sm': 1,
#   'name:sn': 1,
#   'name:so': 1,
#   'name:source': 10,
#   'name:sq': 1,
#   'name:sr': 1,
#   'name:srn': 1,
#   'name:ss': 1,
#   'name:stq': 1,
#   'name:su': 1,
#   'name:sv': 1,
#   'name:sw': 1,
#   'name:szl': 1,
#   'name:ta': 1,
#   'name:te': 1,
#   'name:tet': 1,
#   'name:tg': 1,
#   'name:th': 2,
#   'name:tk': 1,
#   'name:tl': 2,
#   'name:tn': 1,
#   'name:to': 1,
#   'name:tpi': 1,
#   'name:tr': 2,
#   'name:ts': 1,
#   'name:tt': 1,
#   'name:tw': 1,
#   'name:ty': 1,
#   'name:tzl': 1,
#   'name:udm': 1,
#   'name:ug': 1,
#   'name:uk': 7,
#   'name:ur': 1,
#   'name:uz': 1,
#   'name:vec': 1,
#   'name:vep': 1,
#   'name:vi': 1,
#   'name:vls': 1,
#   'name:vo': 1,
#   'name:wa': 1,
#   'name:war': 1,
#   'name:wo': 1,
#   'name:wuu': 1,
#   'name:xal': 1,
#   'name:xh': 1,
#   'name:xmf': 1,
#   'name:yi': 2,
#   'name:yo': 1,
#   'name:za': 1,
#   'name:zea': 1,
#   'name:zh': 3,
#   'name:zh-classical': 1,
#   'name:zh-min-nan': 1,
#   'name:zh-yue': 1,
#   'name:zu': 1,
#   'name_1': 3802,
#   'name_2': 245,
#   'name_3': 27,
#   'name_4': 1,
#   'natural': 10119,
#   'navigationaid': 2,
#   'network': 187,
#   'nist:fips_code': 4,
#   'nist:state_fips': 4,
#   'noexit': 181,
#   'noname': 5,
#   'noref': 67,
#   'note': 517,
#   'note:highway': 2,
#   'note:lanes': 859,
#   'note:name': 158,
#   'note:oneway:flow': 3,
#   'note:operator': 35,
#   'note:ref': 60,
#   'noten': 1,
#   'ntd_id': 8304,
#   'nudism': 2,
#   'odbl': 17,
#   'office': 56,
#   'official_name': 12,
#   'official_name:vi': 1,
#   'old_name': 313,
#   'old_name:vi': 1,
#   'old_railway_operator': 226,
#   'old_ref': 487,
#   'old_ref:1945': 2593,
#   'old_ref:pre_1945': 996,
#   'oneway': 21162,
#   'oneway:bicycle': 4,
#   'oneway:flow': 1104,
#   'opening_hours': 237,
#   'operator': 12082,
#   'organic': 3,
#   'outdoor_seating': 29,
#   'owner': 5,
#   'par': 163,
#   'park_ride': 80,
#   'parking': 666,
#   'parking:lane:right': 1,
#   'passenger': 2,
#   'passing_places': 1,
#   'payment:american_express': 1,
#   'payment:bitcoin': 75,
#   'payment:cash': 2,
#   'payment:coins': 2,
#   'payment:credit_cards': 1,
#   'payment:debits_cards': 1,
#   'payment:discover_card': 1,
#   'payment:litecoin': 5,
#   'payment:mastercard': 1,
#   'payment:paypal': 1,
#   'payment:visa': 1,
#   'phone': 532,
#   'place': 926,
#   'playground': 14,
#   'population': 100,
#   'population:date': 4,
#   'postal_code': 8,
#   'power': 21542,
#   'power_supply': 2,
#   'pram': 2,
#   'proposed': 49,
#   'protect_class': 1,
#   'provided_for:adult': 1,
#   'psv': 1,
#   'public_transport': 10,
#   'public_transport:version': 2,
#   'radar': 1,
#   'railway': 1799,
#   'railway_milepost': 102,
#   'rcn': 326,
#   'rcn_ref': 46,
#   'recycling_type': 3,
#   'ref': 9014,
#   'ref:fips': 1,
#   'ref:nrhp': 1,
#   'ref:store_number': 2,
#   'reg_name': 39,
#   'religion': 580,
#   'residential': 46,
#   'restaurant': 6,
#   'restriction': 224,
#   'roof:colour': 44,
#   'roof:direction': 1,
#   'roof:height': 2,
#   'roof:material': 37,
#   'roof:shape': 139,
#   'route': 331,
#   'route_ref': 8304,
#   'sac_scale': 2,
#   'salt': 119,
#   'scenic': 139,
#   'seamark:beacon_lateral:category': 6,
#   'seamark:buoy_lateral:category': 2,
#   'seamark:buoy_lateral:colour': 2,
#   'seamark:buoy_lateral:system': 1,
#   'seamark:harbour:category': 1,
#   'seamark:mooring:category': 13,
#   'seamark:small_craft_facility:category': 10,
#   'seamark:type': 55,
#   'second_hand': 1,
#   'segregated': 10,
#   'service': 10004,
#   'service:bicycle:chain_tool': 7,
#   'service:bicycle:pump': 3,
#   'service:bicycle:retail': 2,
#   'services': 16,
#   'shelter': 38,
#   'shelter_type': 45,
#   'ship': 40,
#   'shop': 886,
#   'shop_1': 1,
#   'short_name': 84,
#   'short_name:vi': 1,
#   'sidewalk': 6624,
#   'ski': 2,
#   'smoking': 58,
#   'smoothness': 20,
#   'snowmobile': 2,
#   'socket:nema_5_15': 1,
#   'socket:type1': 1,
#   'source': 34692,
#   'source:FIXME': 1,
#   'source:access': 1,
#   'source:addr': 4,
#   'source:date': 8,
#   'source:deep_draft': 32,
#   'source:depth': 34,
#   'source:description': 1,
#   'source:geometry': 90,
#   'source:hgv:national_network': 441,
#   'source:highway': 4,
#   'source:maxspeed': 6497,
#   'source:name': 46,
#   'source:network': 6,
#   'source:noname': 5,
#   'source:oneway': 1,
#   'source:oneway:flow': 139,
#   'source:pkey': 1,
#   'source:population': 4,
#   'source:ref': 1,
#   'source_ref': 1,
#   'sport': 2085,
#   'sport_1': 1,
#   'stars': 3,
#   'start_date': 68,
#   'state': 4,
#   'stile': 1,
#   'stop_name': 1,
#   'structure': 129,
#   'substation': 254,
#   'suite': 1,
#   'supervised': 57,
#   'support': 2,
#   'surface': 11604,
#   'surveillance': 2,
#   'symbol': 17,
#   'takeaway': 26,
#   'tee': 112,
#   'tents': 2,
#   'theatre:genre': 1,
#   'theatre:type': 1,
#   'tiger:CLASSFP': 185,
#   'tiger:CPI': 185,
#   'tiger:FUNCSTAT': 185,
#   'tiger:LSAD': 185,
#   'tiger:MTFCC': 185,
#   'tiger:NAME': 185,
#   'tiger:NAMELSAD': 185,
#   'tiger:PCICBSA': 185,
#   'tiger:PCINECTA': 185,
#   'tiger:PLACEFP': 185,
#   'tiger:PLACENS': 185,
#   'tiger:PLCIDFP': 185,
#   'tiger:STATEFP': 185,
#   'tiger:cfcc': 88176,
#   'tiger:county': 88356,
#   'tiger:name': 1,
#   'tiger:name_base': 81827,
#   'tiger:name_base_1': 5570,
#   'tiger:name_base_2': 518,
#   'tiger:name_base_3': 68,
#   'tiger:name_base_4': 3,
#   'tiger:name_direction_prefix': 52746,
#   'tiger:name_direction_prefix_1': 1770,
#   'tiger:name_direction_prefix_2': 144,
#   'tiger:name_direction_prefix_3': 13,
#   'tiger:name_direction_suffix': 2726,
#   'tiger:name_direction_suffix_1': 143,
#   'tiger:name_direction_suffix_2': 11,
#   'tiger:name_direction_suffix_3': 1,
#   'tiger:name_type': 79221,
#   'tiger:name_type_1': 3647,
#   'tiger:name_type_2': 334,
#   'tiger:name_type_3': 31,
#   'tiger:name_type_4': 2,
#   'tiger:reviewed': 87407,
#   'tiger:separated': 5835,
#   'tiger:source': 6790,
#   'tiger:tlid': 6784,
#   'tiger:upload_uuid': 6784,
#   'tiger:zip_left': 65459,
#   'tiger:zip_left_1': 2408,
#   'tiger:zip_left_2': 614,
#   'tiger:zip_left_3': 242,
#   'tiger:zip_left_4': 85,
#   'tiger:zip_right': 63253,
#   'tiger:zip_right_1': 922,
#   'tiger:zip_right_146': 1,
#   'tiger:zip_right_147': 1,
#   'tiger:zip_right_2': 259,
#   'tiger:zip_right_3': 106,
#   'tiger:zip_right_4': 36,
#   'tiger:zip_right_5': 1,
#   'tiger:zip_rightjun': 1,
#   'timezone': 4,
#   'timezone:note': 1,
#   'to': 7,
#   'toilets': 4,
#   'toilets:disposal': 4,
#   'toilets:wheelchair': 1,
#   'toll': 2200,
#   'toll:bicycle': 19,
#   'toll:hov': 134,
#   'tourism': 669,
#   'tower': 2,
#   'tower:construction': 1,
#   'tower:type': 256,
#   'tracks': 2,
#   'tracktype': 87,
#   'traffic_calming': 102,
#   'traffic_sign': 221,
#   'traffic_signals': 108,
#   'traffic_signals:sound': 1,
#   'trail_visibility': 17,
#   'transformer': 3,
#   'tunnel': 911,
#   'turn:lanes': 130,
#   'turn:lanes:backward': 2,
#   'turn:lanes:forward': 3,
#   'type': 2461,
#   'unsigned_ref': 2565,
#   'url': 18,
#   'usage': 157,
#   'vehicle': 3,
#   'vehicle:lanes': 2,
#   'vending': 4,
#   'verified': 1,
#   'voltage': 884,
#   'water': 531,
#   'waterway': 3920,
#   'website': 815,
#   'wetap:photo': 1,
#   'wetap:status': 6,
#   'wetland': 34,
#   'wheelchair': 154,
#   'width': 33,
#   'wifi': 7,
#   'wikidata': 9,
#   'wikipedia': 322,
#   'wood': 1,
#   'yards': 1,
#   'zip_right': 1,
#   'zoo': 1})

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.cElementTree as ET
import pprint
import re
"""
Your task is to explore the data a bit more.
The first task is a fun one - find out how many unique users
have contributed to the map in this particular area!

The function process_map should return a set of unique user IDs ("uid")
"""

def get_user(element):
	if 'uid' in element.attrib.keys():
		user = element.attrib['uid']

		return user


def process_map(filename):
    users = set()
    user_list = []
    for _, element in ET.iterparse(filename):
	  	if 'uid' in element.attrib.keys():
			user = element.attrib['uid']
  			user_list.append(user)

    users = set(user_list)
    return users


def test():
    osm_file = open("/Users/jpowell/Downloads/data/miami_florida_sample.osm", "r")

    users = process_map(osm_file)
    print len(users)
    pprint.pprint(users)


if __name__ == "__main__":
    test()
# Out:
# 668
# set(['1007528',
#      '1012362',
#      '1018224',
#      '102691',
#      '103107',
#      '103253',
#      '1043009',
#      '104519',
#      '104962',
#      '1051550',
#      '105255',
#      '10557',
#      '1058308',
#      '10786',
#      '1087647',
#      '108775',
#      '1090081',
#      '10927',
#      '1093154',
#      '109570',
#      '1096309',
#      '110263',
#      '110489',
#      '110639',
#      '111159',
#      '11154',
#      '1119200',
#      '11374',
#      '115102',
#      '11547',
#      '115918',
#      '1163648',
#      '1163952',
#      '1171517',
#      '118021',
#      '118048',
#      '119748',
#      '1198074',
#      '1198303',
#      '119881',
#      '121264',
#      '1214881',
#      '12290',
#      '123633',
#      '1240849',
#      '1244855',
#      '1246157',
#      '124815',
#      '1249205',
#      '1251419',
#      '1260280',
#      '128470',
#      '12919',
#      '129232',
#      '1298694',
#      '1306',
#      '131059',
#      '131200',
#      '1318885',
#      '1330847',
#      '1339815',
#      '13413',
#      '1342842',
#      '1342868',
#      '1346164',
#      '135163',
#      '1352459',
#      '135329',
#      '137',
#      '1373621',
#      '1376118',
#      '1390253',
#      '139562',
#      '139856',
#      '1403907',
#      '1405281',
#      '1408522',
#      '1419649',
#      '1425269',
#      '142710',
#      '142776',
#      '1430450',
#      '143134',
#      '1431737',
#      '14390',
#      '145201',
#      '145231',
#      '146680',
#      '147510',
#      '147871',
#      '1480053',
#      '1483073',
#      '14850',
#      '1494110',
#      '1495201',
#      '1501508',
#      '150272',
#      '150368',
#      '152074',
#      '153305',
#      '1535212',
#      '153651',
#      '153669',
#      '153711',
#      '155066',
#      '1555726',
#      '1556188',
#      '15686',
#      '157589',
#      '158204',
#      '15877',
#      '160138',
#      '160651',
#      '160949',
#      '16102',
#      '161269',
#      '162340',
#      '1624486',
#      '1631775',
#      '163673',
#      '1651798',
#      '1658646',
#      '1667251',
#      '167009',
#      '1679',
#      '1679807',
#      '1687166',
#      '168862',
#      '169004',
#      '1694420',
#      '169474',
#      '1694880',
#      '1709203',
#      '1714996',
#      '171538',
#      '172061',
#      '1723831',
#      '1724242',
#      '1726955',
#      '1729779',
#      '1730825',
#      '1731253',
#      '17427',
#      '1745187',
#      '1748272',
#      '1750007',
#      '1750720',
#      '1753050',
#      '175600',
#      '1776782',
#      '177771',
#      '1778799',
#      '1778977',
#      '1782960',
#      '1783785',
#      '1783862',
#      '17857',
#      '178626',
#      '1788833',
#      '1795637',
#      '1802220',
#      '18069',
#      '181135',
#      '1813115',
#      '1813171',
#      '181582',
#      '1817650',
#      '1819820',
#      '1827167',
#      '1829683',
#      '1841384',
#      '1850423',
#      '1850567',
#      '1856433',
#      '1860204',
#      '1865164',
#      '1866562',
#      '1869502',
#      '1870331',
#      '187433',
#      '187839',
#      '187849',
#      '1881064',
#      '1883379',
#      '1884214',
#      '1884889',
#      '1888341',
#      '190869',
#      '191339',
#      '1916438',
#      '1919081',
#      '192905',
#      '193399',
#      '1939272',
#      '195702',
#      '1959015',
#      '1963841',
#      '196617',
#      '1967719',
#      '1969572',
#      '19735',
#      '1979555',
#      '1979756',
#      '198440',
#      '1985907',
#      '2003792',
#      '2006475',
#      '200922',
#      '2012449',
#      '201359',
#      '2025754',
#      '2026966',
#      '202868',
#      '2031988',
#      '2041218',
#      '2053369',
#      '205523',
#      '2058761',
#      '2059301',
#      '2064884',
#      '2065004',
#      '2072931',
#      '207581',
#      '207745',
#      '2082922',
#      '2082952',
#      '2082955',
#      '2083139',
#      '2087301',
#      '2089642',
#      '2094226',
#      '211406',
#      '2115749',
#      '2118269',
#      '2118323',
#      '2127730',
#      '2135320',
#      '213570',
#      '2135733',
#      '2138947',
#      '2139707',
#      '2143702',
#      '2147445',
#      '214758',
#      '2154087',
#      '2167889',
#      '2174002',
#      '2177834',
#      '2214041',
#      '2214259',
#      '221878',
#      '2219338',
#      '2219985',
#      '2222901',
#      '2226712',
#      '2226854',
#      '2237867',
#      '2260007',
#      '2261866',
#      '2265252',
#      '22701',
#      '22714',
#      '228353',
#      '229013',
#      '229814',
#      '229878',
#      '229916',
#      '230350',
#      '2306749',
#      '2309492',
#      '2317678',
#      '2318',
#      '232126',
#      '2325238',
#      '233248',
#      '2349071',
#      '236172',
#      '237223',
#      '23762',
#      '2377377',
#      '238584',
#      '2397497',
#      '239998',
#      '2400449',
#      '2406049',
#      '2407563',
#      '2422391',
#      '24247',
#      '2426948',
#      '2427130',
#      '2428402',
#      '2441939',
#      '24440',
#      '2449734',
#      '2452155',
#      '245827',
#      '2458458',
#      '2459734',
#      '245990',
#      '2473576',
#      '24748',
#      '2475423',
#      '2483888',
#      '2483892',
#      '2483903',
#      '2497300',
#      '2499031',
#      '2500700',
#      '2511706',
#      '2512300',
#      '2512306',
#      '2514757',
#      '2516309',
#      '2516313',
#      '2516316',
#      '2522643',
#      '2527838',
#      '252811',
#      '2533093',
#      '2538098',
#      '2539713',
#      '2542089',
#      '2544441',
#      '2550539',
#      '255141',
#      '2554698',
#      '2569968',
#      '2574196',
#      '258131',
#      '259657',
#      '25996',
#      '260703',
#      '262151',
#      '26299',
#      '263430',
#      '2644101',
#      '2675037',
#      '2676482',
#      '2679756',
#      '2699096',
#      '2748195',
#      '2755647',
#      '2758805',
#      '2766625',
#      '2768606',
#      '2786303',
#      '2803613',
#      '281267',
#      '2813997',
#      '28145',
#      '2815098',
#      '2820500',
#      '2823295',
#      '2835928',
#      '2844972',
#      '2847906',
#      '2847988',
#      '2858919',
#      '2859402',
#      '2867366',
#      '2870598',
#      '28775',
#      '2879939',
#      '2880275',
#      '2880497',
#      '28852',
#      '28868',
#      '28923',
#      '2895198',
#      '2903405',
#      '2905914',
#      '290680',
#      '2906976',
#      '292665',
#      '2933274',
#      '2942085',
#      '294614',
#      '2953389',
#      '2954994',
#      '296191',
#      '2972431',
#      '2975800',
#      '2975833',
#      '297594',
#      '298201',
#      '2983905',
#      '298429',
#      '2985232',
#      '3000556',
#      '30035',
#      '300459',
#      '3019337',
#      '3021019',
#      '30284',
#      '302871',
#      '30383',
#      '30521',
#      '30587',
#      '305985',
#      '308',
#      '30854',
#      '3093601',
#      '3097641',
#      '310589',
#      '3106586',
#      '31231',
#      '313192',
#      '3132700',
#      '3147171',
#      '316868',
#      '3214791',
#      '322785',
#      '3234',
#      '323757',
#      '3243496',
#      '3245803',
#      '3247715',
#      '3258663',
#      '3282758',
#      '32952',
#      '3301319',
#      '3307850',
#      '3312693',
#      '3320844',
#      '3321357',
#      '3329241',
#      '3338882',
#      '334389',
#      '3356200',
#      '3363664',
#      '336460',
#      '3369384',
#      '337684',
#      '3390702',
#      '3394687',
#      '3397088',
#      '339917',
#      '3406980',
#      '344561',
#      '345754',
#      '351713',
#      '35243',
#      '353101',
#      '354170',
#      '355242',
#      '355617',
#      '35585',
#      '3560',
#      '3582',
#      '358273',
#      '360392',
#      '36121',
#      '361348',
#      '362391',
#      '364',
#      '36443',
#      '36605',
#      '368412',
#      '369983',
#      '37137',
#      '37392',
#      '374955',
#      '379440',
#      '37987',
#      '380298',
#      '383288',
#      '38487',
#      '384894',
#      '386615',
#      '390024',
#      '39060',
#      '39457',
#      '39504',
#      '396743',
#      '3980',
#      '398300',
#      '398817',
#      '3990',
#      '401102',
#      '401490',
#      '40397',
#      '4049',
#      '405293',
#      '4054',
#      '408776',
#      '412146',
#      '413047',
#      '414318',
#      '418930',
#      '42191',
#      '42429',
#      '425877',
#      '429761',
#      '430251',
#      '431056',
#      '434941',
#      '436419',
#      '437598',
#      '441065',
#      '44221',
#      '443130',
#      '44659',
#      '446964',
#      '447903',
#      '449569',
#      '45027',
#      '451048',
#      '451693',
#      '45263',
#      '458834',
#      '46140',
#      '463963',
#      '469297',
#      '4697',
#      '4732',
#      '474051',
#      '475877',
#      '47892',
#      '479256',
#      '481116',
#      '488866',
#      '49031',
#      '49351',
#      '495739',
#      '496835',
#      '496923',
#      '499783',
#      '5013',
#      '507640',
#      '508',
#      '51045',
#      '510836',
#      '51324',
#      '515211',
#      '5164',
#      '520239',
#      '522978',
#      '525566',
#      '52626',
#      '526849',
#      '527105',
#      '52797',
#      '5286',
#      '529207',
#      '529645',
#      '53050',
#      '53073',
#      '531879',
#      '533465',
#      '534149',
#      '5359',
#      '54626',
#      '54759',
#      '550560',
#      '554234',
#      '557679',
#      '557948',
#      '558778',
#      '55916',
#      '560392',
#      '564222',
#      '564585',
#      '567034',
#      '567344',
#      '567601',
#      '569208',
#      '5715',
#      '571827',
#      '573196',
#      '5748',
#      '575547',
#      '580516',
#      '580542',
#      '586214',
#      '589596',
#      '590608',
#      '590907',
#      '592017',
#      '595246',
#      '599436',
#      '599469',
#      '60110',
#      '601170',
#      '609937',
#      '612391',
#      '61599',
#      '616152',
#      '617465',
#      '618377',
#      '618879',
#      '620171',
#      '625059',
#      '626690',
#      '627111',
#      '630068',
#      '632378',
#      '637742',
#      '64065',
#      '651869',
#      '655370',
#      '660222',
#      '663790',
#      '664301',
#      '665694',
#      '667073',
#      '669873',
#      '67862',
#      '684651',
#      '685704',
#      '68982',
#      '69853',
#      '70',
#      '703517',
#      '706587',
#      '70696',
#      '707052',
#      '710623',
#      '711265',
#      '714898',
#      '7168',
#      '718617',
#      '7203',
#      '722137',
#      '757042',
#      '757237',
#      '76002',
#      '775666',
#      '78656',
#      '79933',
#      '818552',
#      '822818',
#      '82820',
#      '828956',
#      '833786',
#      '834399',
#      '837425',
#      '84054',
#      '84805',
#      '84873',
#      '86027',
#      '8703',
#      '870861',
#      '879678',
#      '88164',
#      '88337',
#      '88961',
#      '8909',
#      '89098',
#      '894121',
#      '897213',
#      '902646',
#      '912425',
#      '914807',
#      '91490',
#      '92286',
#      '93788',
#      '941449',
#      '9437',
#      '94578',
#      '95387',
#      '95598',
#      '95842',
#      '959039',
#      '969831',
#      '985060',
#      '987393',
#      '994975',
#      '999995'])

# %%
"""
Your task in this exercise has two steps:

- audit the OSMFILE and change the variable 'mapping' to reflect the changes needed to fix
    the unexpected street types to the appropriate ones in the expected list.
    You have to add mappings only for the actual problems you find in this OSMFILE,
    not a generalized solution, since that may and will depend on the particular area you are auditing.
- write the update_name function, to actually fix the street name.
    The function takes a string with street name as an argument and should return the fixed name
    We have provided a simple test so that you see what exactly is expected
"""
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint


street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
street_direction_re = re.compile(r'^\w+', re.IGNORECASE)

expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road",
            "Trail", "Parkway", "Commons", "Circle", "Crescent", "Highway", "Manor", "Terrace",
            "Trace", "Way", "Causeway", "Point", "State Road"]

expected_direction = ["North", "South", "East", "West", "Northeast", "Northwest", "Southeast", "Southwest"]

# UPDATE THIS VARIABLE
mapping = { "AVE": "Avenue",
            "Ave": "Avenue",
            "Ave.": "Avenue",
            "ave": "Avenue",
            "BLVD": "Boulevard",
            "Blvd": "Boulevard",
            "Blvd.": "Boulevard",
            "Cir": "Circle",
            "Cirlce": "Circle",
            "Cres": "Crescent",
            "Ct": "Court",
            "Dr": "Drive",
            "Druve": "Drive",
            "HWY": "Highway",
            "Hwy": "Highway",
            "Ln": "Lane",
            "Mnr": "Manor",
            "Pkwy": "Parkway",
            "Pl": "Place",
            "Pt": "Point",
            "ST": "Street",
            "st": "Street",
            "St": "Street",
            "Sr": "State Road",
            "street": "Street",
            "St.": "Street",
            "RD": "Road",
            "Rd": "Road",
            "Rd.": "Road",
            "Ter": "Terrace",
            "Trce": "Trace",
            "Trl": "Trail", 
            "NW": "Northwest",
            "Cv": "Cove",
            "Hwy-1": "US Highway 1",
            "Ste": "Suite",
            "Spgs" : ""
            }

mapping_direction = {
            "N": "North",
            "S": "South",
            "E": "East",
            "W": "West",
            "NE": "Northeast",
            "Norhwest": "Northwest",
            "NW": "Northwest",
            "SE": "Southeast",
            "SW": "Southwest",
            "sw": "Southwest",
            "southwest": "Southwest", 
            "St": "Saint",
            "Hwy": "Highway", 
            "royal": "Royal",
            "wellington": "Wellington"
}

def audit_street_type(street_types, street_name):
    m = street_type_re.search(update_name(street_name, mapping))
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def audit_street_direction(street_directions, street_name):
    m = street_direction_re.search(update_name(street_name, mapping_direction))
    if m:
        street_direction = m.group()
        if street_direction not in expected_direction:
            street_directions[street_direction].add(street_name)

            
def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def is_zip_code(elem):
    return (elem.attrib['k'] == "addr:postcode")


def audit_type(osmfile):
    osm_file = osmfile
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])

    return street_types


def audit_direction(osmfile):
    osm_file = osmfile
    street_directions = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_direction(street_directions, tag.attrib['v'])
                if is_zip_code(tag):                  
                    zip_code = re.sub(r"\D", "", tag.attrib['v'])
                    print zip_code[0:5]
  
    return street_directions


def update_name(name, mapping):
    m = street_type_re.search(name)
    if m:
        street_type = m.group()
        if street_type in mapping:
            name = name.replace(street_type, mapping[street_type])

    a = street_direction_re.search(name)
    if a: 
        street_direction = a.group()
        if street_direction in mapping:
            name = name.replace(street_direction, mapping[street_direction])
            
    return name


def test():
    osmfile = open("/Users/jpowell/Downloads/data/miami_florida_sample.osm", "r")
    
#     st_types = audit_type(osmfile)
#     print len(st_types)
#     pprint.pprint(dict(st_types))


    st_directions = audit_direction(osmfile)
    print len(st_directions)
#     pprint.pprint(dict(st_directions))
    
    
#     for st_type, ways in st_types.iteritems():
#         for name in ways:
#             better_name = update_name(name, mapping)
#             print name, "=>", better_name

#     for st_direction, ways in st_directions.iteritems():
#         for name in ways:
#             print name
#             better_name = update_name(name, mapping_direction)
#             print better_name


if __name__ == '__main__':
    test()
# Out:
# 33144
# 33444
# 33308
# 33130
# 33187
# 33143
# 33134
# 33060
# 33060
# 33316
# 33060
# 33132
# 33139
# 33139
# 33139
# 33139
# 33172
# 33029
# 33316
# 33065
# 33460
# 33133
# 33325
# 33189
# 33157
# 33062
# 33186
# 33012
# 33138
# 33155
# 33401
# 33155
# 33132
# 33156
# 33139
# 33461
# 33127
# 33144
# 33019
# 33180
# 33138
# 33004
# 33326
# 33326
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33326
# 33326
# 33326
# 33326
# 33326
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33326
# 33326
# 33327
# 33326
# 33326
# 33326
# 33327
# 33327
# 33326
# 33326
# 33326
# 33326
# 33327
# 33327
# 33327
# 33327
# 33326
# 33326
# 33326
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33326
# 33326
# 33327
# 33327
# 33326
# 33326
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33326
# 33326
# 33327
# 33327
# 33327
# 33327
# 33326
# 33326
# 33326
# 33326
# 33327
# 33327
# 33326
# 33326
# 33327
# 33327
# 33326
# 33326
# 33327
# 33326
# 33327
# 33327
# 33326
# 33326
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33327
# 33326
# 33326
# 33326
# 33327
# 33327
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33326
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33327
# 33326
# 33326
# 33327
# 33327
# 33327
# 33327
# 33327
# 33326
# 33326
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33326
# 33326
# 33326
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33326
# 33327
# 33326
# 33327
# 33327
# 33327
# 33326
# 33327
# 33326
# 33327
# 33326
# 33326
# 33326
# 33327
# 33327
# 33326
# 33327
# 33327
# 33327
# 33326
# 33326
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33326
# 33326
# 33326
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33326
# 33327
# 33326
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33326
# 33326
# 33326
# 33327
# 33327
# 33327
# 33326
# 33326
# 33326
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33326
# 33326
# 33326
# 33327
# 33327
# 33327
# 33326
# 33327
# 33326
# 33327
# 33326
# 33326
# 33327
# 33327
# 33326
# 33327
# 33326
# 33326
# 33326
# 33327
# 33327
# 33327
# 33326
# 33326
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33326
# 33327
# 33327
# 33327
# 33326
# 33326
# 33327
# 33326
# 33326
# 33326
# 33326
# 33326
# 33327
# 33326
# 33327
# 33327
# 33326
# 33326
# 33327
# 33326
# 33326
# 33327
# 33327
# 33327
# 33326
# 33326
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33326
# 33326
# 33327
# 33326
# 33327
# 33326
# 33326
# 33326
# 33326
# 33326
# 33327
# 33327
# 33326
# 33327
# 33327
# 33327
# 33326
# 33326
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33326
# 33326
# 33326
# 33326
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33326
# 33326
# 33327
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33326
# 33327
# 33327
# 33327
# 33326
# 33326
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33326
# 33327
# 33326
# 33327
# 33326
# 33327
# 33326
# 33327
# 33326
# 33327
# 33327
# 33327
# 33326
# 33326
# 33327
# 33327
# 33327
# 33326
# 33326
# 33326
# 33326
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33326
# 33326
# 33327
# 33327
# 33326
# 33327
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33326
# 33327
# 33326
# 33326
# 33327
# 33327
# 33327
# 33326
# 33327
# 33331
# 33331
# 33331
# 33331
# 33327
# 33331
# 33331
# 33326
# 33327
# 33331
# 33326
# 33331
# 33327
# 33327
# 33331
# 33326
# 33331
# 33331
# 33331
# 33327
# 33331
# 33331
# 33326
# 33331
# 33327
# 33331
# 33331
# 33331
# 33327
# 33331
# 33326
# 33331
# 33326
# 33327
# 33326
# 33326
# 33327
# 33327
# 33327
# 33331
# 33326
# 33331
# 33331
# 33326
# 33331
# 33331
# 33326
# 33331
# 33331
# 33326
# 33331
# 33331
# 33327
# 33331
# 33327
# 33327
# 33327
# 33326
# 33326
# 33326
# 33331
# 33331
# 33331
# 33327
# 33327
# 33326
# 33327
# 33327
# 33331
# 33331
# 33326
# 33331
# 33331
# 33331
# 33331
# 33331
# 33327
# 33326
# 33331
# 33331
# 33331
# 33331
# 33331
# 33331
# 33331
# 33331
# 33326
# 33331
# 33331
# 33326
# 33327
# 33326
# 33326
# 33326
# 33331
# 33331
# 33331
# 33331
# 33326
# 33327
# 33331
# 33331
# 33331
# 33331
# 33327
# 33331
# 33327
# 33331
# 33331
# 33327
# 33326
# 33327
# 33326
# 33326
# 33327
# 33326
# 33326
# 33331
# 33327
# 33326
# 33326
# 33326
# 33326
# 33327
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33327
# 33326
# 33331
# 33326
# 33326
# 33326
# 33326
# 33326
# 33331
# 33326
# 33326
# 33326
# 33326
# 33327
# 33331
# 33331
# 33326
# 33331
# 33331
# 33331
# 33326
# 33326
# 33331
# 33326
# 33331
# 33326
# 33331
# 33331
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33327
# 33326
# 33326
# 33326
# 33326
# 33327
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33327
# 33326
# 33326
# 33326
# 33327
# 33326
# 33326
# 33327
# 33326
# 33327
# 33326
# 33327
# 33326
# 33327
# 33326
# 33327
# 33327
# 33327
# 33326
# 33326
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33326
# 33326
# 33327
# 33326
# 33326
# 33327
# 33326
# 33327
# 33327
# 33327
# 33326
# 33327
# 33327
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33326
# 33326
# 33326
# 33327
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33326
# 33327
# 33327
# 33327
# 33332
# 33327
# 33327
# 33327
# 33326
# 33327
# 33326
# 33327
# 33326
# 33327
# 33326
# 33326
# 33327
# 33327
# 33327
# 33326
# 33327
# 33327
# 33332
# 33327
# 33326
# 33327
# 33332
# 33332
# 33332
# 33327
# 33332
# 33327
# 33332
# 33332
# 33332
# 33332
# 33327
# 33327
# 33332
# 33327
# 33332
# 33332
# 33327
# 33332
# 33327
# 33332
# 33332
# 33332
# 33326
# 33332
# 33332
# 33332
# 33332
# 33327
# 33332
# 33332
# 33327
# 33327
# 33326
# 33327
# 33326
# 33327
# 33332
# 33332
# 33327
# 33326
# 33332
# 33332
# 33327
# 33327
# 33327
# 33326
# 33326
# 33326
# 33327
# 33326
# 33326
# 33327
# 33326
# 33326
# 33327
# 33326
# 33326
# 33326
# 33326
# 33327
# 33327
# 33326
# 33327
# 33326
# 33327
# 33326
# 33327
# 33327
# 33326
# 33326
# 33326
# 33326
# 33327
# 33327
# 33327
# 33326
# 33326
# 33326
# 33327
# 33327
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33326
# 33326
# 33326
# 33326
# 33327
# 33327
# 33327
# 33326
# 33327
# 33326
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33326
# 33327
# 33326
# 33327
# 33327
# 33327
# 33326
# 33327
# 33326
# 33326
# 33327
# 33327
# 33327
# 33326
# 33327
# 33326
# 33326
# 33326
# 33326
# 33326
# 33327
# 33326
# 33327
# 33327
# 33326
# 33326
# 33327
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33327
# 0
# 33327
# 33326
# 33327
# 33326
# 33326
# 33327
# 33327
# 33327
# 33327
# 33326
# 33326
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33326
# 33326
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33331
# 33332
# 33332
# 33327
# 33331
# 33332
# 33332
# 33332
# 33332
# 33332
# 33332
# 33332
# 33332
# 33332
# 33332
# 33332
# 33332
# 33332
# 33327
# 33332
# 33332
# 33332
# 33332
# 33327
# 33332
# 33332
# 33332
# 33332
# 33332
# 33332
# 33331
# 33332
# 33332
# 33332
# 33332
# 33331
# 33332
# 33332
# 33332
# 33332
# 33332
# 33331
# 33332
# 33331
# 33332
# 33332
# 33331
# 33331
# 33331
# 33332
# 33326
# 33332
# 33332
# 33331
# 33332
# 33327
# 33331
# 33331
# 33332
# 33332
# 33326
# 33332
# 33331
# 33332
# 33331
# 33332
# 33331
# 33327
# 33332
# 33332
# 33332
# 33327
# 33326
# 33332
# 33327
# 33331
# 33327
# 33327
# 33332
# 33332
# 33332
# 33331
# 33332
# 33326
# 33332
# 33332
# 33332
# 33332
# 33331
# 33331
# 33331
# 33332
# 33332
# 33327
# 33332
# 33331
# 33326
# 33331
# 33331
# 33326
# 33332
# 33331
# 33327
# 33332
# 33331
# 33326
# 33327
# 33326
# 33331
# 33332
# 33331
# 33331
# 33332
# 33327
# 33332
# 33331
# 33331
# 33327
# 33332
# 33331
# 33326
# 33332
# 33332
# 33331
# 33326
# 33331
# 33332
# 33332
# 33332
# 33332
# 33326
# 33332
# 33331
# 33326
# 33331
# 33332
# 33326
# 33326
# 33326
# 33331
# 33331
# 33326
# 33331
# 33331
# 33331
# 33326
# 33331
# 33331
# 33331
# 33331
# 33326
# 33326
# 33326
# 33326
# 33332
# 33327
# 33331
# 33326
# 33331
# 33331
# 33331
# 33326
# 33331
# 33331
# 33331
# 33331
# 33331
# 33331
# 33331
# 33331
# 33331
# 33326
# 33331
# 33331
# 33332
# 33332
# 33331
# 33331
# 33332
# 33331
# 33331
# 33331
# 33331
# 33331
# 33332
# 33331
# 33332
# 33332
# 33331
# 33331
# 33332
# 33331
# 33331
# 33331
# 33331
# 33331
# 33331
# 33331
# 33331
# 33326
# 33332
# 33326
# 33332
# 33331
# 33332
# 33332
# 33326
# 33332
# 33332
# 33332
# 33331
# 33331
# 33332
# 33331
# 33332
# 33331
# 33331
# 33331
# 33332
# 33331
# 33331
# 33331
# 33332
# 33332
# 33332
# 33332
# 33332
# 33331
# 33332
# 33331
# 33331
# 33332
# 33332
# 33332
# 33331
# 33332
# 33327
# 33332
# 33331
# 33331
# 33331
# 33332
# 33326
# 33332
# 33332
# 33332
# 33331
# 33331
# 33332
# 33332
# 33332
# 33326
# 33332
# 33332
# 33332
# 33331
# 33331
# 33332
# 33332
# 33326
# 33331
# 33331
# 33332
# 33327
# 33331
# 33331
# 33331
# 33326
# 33331
# 33331
# 33326
# 33331
# 33332
# 33331
# 33331
# 33326
# 33326
# 33331
# 33331
# 33331
# 33331
# 33327
# 33331
# 33331
# 33331
# 33332
# 33326
# 33331
# 33331
# 33331
# 33331
# 33331
# 33331
# 33331
# 33331
# 33326
# 33331
# 33332
# 33326
# 33331
# 33331
# 33332
# 33331
# 33331
# 33331
# 33332
# 33332
# 33332
# 33331
# 33332
# 33331
# 33331
# 33327
# 33331
# 33331
# 33331
# 33332
# 33332
# 33326
# 33331
# 33332
# 33331
# 33331
# 33331
# 33332
# 33332
# 33327
# 33332
# 33331
# 33331
# 33331
# 33331
# 33326
# 33331
# 33331
# 33331
# 33331
# 33332
# 33331
# 33331
# 33331
# 33331
# 33331
# 33331
# 33326
# 33331
# 33331
# 33331
# 33331
# 33331
# 33331
# 33331
# 33331
# 33331
# 33331
# 33331
# 33326
# 33326
# 33331
# 33332
# 33331
# 33326
# 33326
# 33332
# 33331
# 33331
# 33331
# 33331
# 33326
# 33331
# 33332
# 33327
# 33331
# 33331
# 33326
# 33331
# 33331
# 33331
# 33331
# 33332
# 33331
# 33326
# 33331
# 33331
# 33331
# 33331
# 33331
# 33331
# 33332
# 33331
# 33332
# 33331
# 33331
# 33331
# 33332
# 33331
# 33326
# 33326
# 33331
# 33331
# 33331
# 33331
# 33331
# 33332
# 33331
# 33326
# 33332
# 33331
# 33332
# 33331
# 33331
# 33326
# 33332
# 33331
# 33331
# 33331
# 33326
# 33331
# 33331
# 33332
# 33331
# 33331
# 33331
# 33327
# 33331
# 33331
# 33331
# 33331
# 33332
# 33331
# 33326
# 33331
# 33331
# 33331
# 33326
# 33331
# 33331
# 33331
# 33332
# 33331
# 33332
# 33331
# 33331
# 33327
# 33331
# 33331
# 33331
# 33331
# 33332
# 33331
# 33331
# 33331
# 33331
# 33332
# 33331
# 33331
# 33331
# 33326
# 33331
# 33331
# 33327
# 33331
# 33331
# 33326
# 33331
# 33331
# 33332
# 33331
# 33331
# 33331
# 33326
# 33326
# 33326
# 33326
# 33327
# 33331
# 33331
# 33327
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33327
# 33326
# 33327
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33327
# 33326
# 33326
# 33326
# 33326
# 33326
# 33327
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33327
# 33326
# 33326
# 33326
# 33327
# 33326
# 33326
# 33326
# 33327
# 33326
# 33327
# 33326
# 33327
# 33326
# 33327
# 33327
# 33326
# 33326
# 33326
# 33326
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33327
# 33326
# 33326
# 33326
# 33326
# 33327
# 33326
# 33326
# 33326
# 33326
# 33326
# 33327
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33327
# 33326
# 33326
# 33326
# 33327
# 33326
# 33326
# 33326
# 33326
# 33326
# 33326
# 33327
# 33326
# 33327
# 33326
# 33327
# 33326
# 33326
# 33327
# 33326
# 33326
# 33326
# 33326
# 33326
# 33327
# 33326
# 33327
# 33326
# 33326
# 33326
# 33327
# 33327
# 33326
# 33326
# 33326
# 33327
# 33327
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33326
# 33326
# 33327
# 33326
# 33326
# 33327
# 33326
# 33326
# 33326
# 33327
# 33326
# 33326
# 33326
# 33327
# 33327
# 33327
# 33326
# 33327
# 33326
# 33327
# 33327
# 33327
# 33326
# 33326
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33326
# 33326
# 33327
# 33326
# 33326
# 33327
# 33327
# 33327
# 33327
# 33326
# 33326
# 33326
# 33327
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33326
# 33326
# 33326
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33326
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33327
# 33327
# 33326
# 33327
# 33326
# 33327
# 33326
# 33327
# 33327
# 33326
# 33326
# 33326
# 33326
# 33326
# 33327
# 33326
# 33326
# 33327
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33326
# 33327
# 33327
# 33326
# 33326
# 33327
# 33326
# 33327
# 33326
# 33326
# 33326
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33326
# 33327
# 33326
# 33326
# 33327
# 33326
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33326
# 33326
# 33327
# 33327
# 33327
# 33326
# 33326
# 33327
# 33326
# 33326
# 33327
# 33326
# 33327
# 33326
# 33327
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33327
# 33326
# 33326
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33326
# 33326
# 33327
# 33327
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33326
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33326
# 33327
# 33326
# 33327
# 33326
# 33326
# 33327
# 33327
# 33327
# 33327
# 33326
# 33327
# 33326
# 33327
# 33327
# 33327
# 33326
# 33326
# 33326
# 33174
# 33034
# 33408
# 33062
# 33316
# 33004
# 33172
# 33024
# 33401
# 33301
# 33309
# 33125
# 33009
# 33409
# 33027
# 33461
# 33019
# 33449
# 33414
# 33414
# 33414
# 33414
# 33414
# 33414
# 33414
# 33431
# 33445
# 33319
# 33319
# 33319
# 33414
# 33313
# 33487
# 33314
# 33326
# 33131
# 33426
# 33140
# 33140
# 33433
# 33161
# 33025
# 33496
# 33166
# 33470
# 33034
# 33328
# 33023
# 33157
# 33176
# 33319
# 33181
# 33309
# 33325
# 33403
# 33140
# 33154
# 33154
# 33160
# 33139
# 33180
# 33304
# 33027
# 33129
# 33138
# 33154
# 33460
# 33431
# 33444
# 33139
# 33131
# 33131
# 33131
# 33131
# 33141
# 33137
# 33178
# 33178
# 33127
# 33304
# 33304
# 33308
# 33304
# 33319
# 33322
# 33004
# 33304
# 33304
# 33304
# 33304
# 33431
# 33126
# 33146
# 33431
# 33408
# 33162
# 33467
# 33027
# 33414
# 33065
# 33146
# 33196
# 33140
# 386

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.cElementTree as ET
import pprint
import re
import codecs
import json
from collections import defaultdict
"""
Your task is to wrangle the data and transform the shape of the data
into the model we mentioned earlier. The output should be a list of dictionaries
that look like this:

{
"id": "2406124091",
"type: "node",
"visible":"true",
"created": {
          "version":"2",
          "changeset":"17206049",
          "timestamp":"2013-08-03T16:43:42Z",
          "user":"linuxUser16",
          "uid":"1219059"
        },
"pos": [41.9757030, -87.6921867],
"address": {
          "housenumber": "5157",
          "postcode": "60625",
          "street": "North Lincoln Ave"
        },
"amenity": "restaurant",
"cuisine": "mexican",
"name": "La Cabana De Don Luis",
"phone": "1 (773)-271-5176"
}

You have to complete the function 'shape_element'.
We have provided a function that will parse the map file, and call the function with the element
as an argument. You should return a dictionary, containing the shaped data for that element.
We have also provided a way to save the data in a file, so that you could use
mongoimport later on to import the shaped data into MongoDB.

Note that in this exercise we do not use the 'update street name' procedures
you worked on in the previous exercise. If you are using this code in your final
project, you are strongly encouraged to use the code from previous exercise to
update the street names before you save them to JSON.

In particular the following things should be done:
- you should process only 2 types of top level tags: "node" and "way"
- all attributes of "node" and "way" should be turned into regular key/value pairs, except:
    - attributes in the CREATED array should be added under a key "created"
    - attributes for latitude and longitude should be added to a "pos" array,
      for use in geospacial indexing. Make sure the values inside "pos" array are floats
      and not strings.
- if second level tag "k" value contains problematic characters, it should be ignored
- if second level tag "k" value starts with "addr:", it should be added to a dictionary "address"
- if second level tag "k" value does not start with "addr:", but contains ":", you can process it
  same as any other tag.
- if there is a second ":" that separates the type/direction of a street,
  the tag should be ignored, for example:

<tag k="addr:housenumber" v="5158"/>
<tag k="addr:street" v="North Lincoln Avenue"/>
<tag k="addr:street:name" v="Lincoln"/>
<tag k="addr:street:prefix" v="North"/>
<tag k="addr:street:type" v="Avenue"/>
<tag k="amenity" v="pharmacy"/>

  should be turned into:

{...
"address": {
    "housenumber": 5158,
    "street": "North Lincoln Avenue"
}
"amenity": "pharmacy",
...
}

- for "way" specifically:

  <nd ref="305896090"/>
  <nd ref="1719825889"/>

should be turned into
"node_refs": ["305896090", "1719825889"]
"""


lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

CREATED = ["version", "changeset", "timestamp", "user", "uid"]

MAPPING = { "AVE": "Avenue",
            "Ave": "Avenue",
            "Ave.": "Avenue",
            "ave": "Avenue",
            "BLVD": "Boulevard",
            "Blvd": "Boulevard",
            "Blvd.": "Boulevard",
            "Cir": "Circle",
            "Cirlce": "Circle",
            "Cres": "Crescent",
            "Ct": "Court",
            "Dr": "Drive",
            "Druve": "Drive",
            "HWY": "Highway",
            "Hwy": "Highway",
            "Ln": "Lane",
            "Mnr": "Manor",
            "Pkwy": "Parkway",
            "Pl": "Place",
            "Pt": "Point",
            "ST": "Street",
            "st": "Street",
            "St": "Street",
            "Sr": "State Road",
            "street": "Street",
            "St.": "Street",
            "RD": "Road",
            "Rd": "Road",
            "Rd.": "Road",
            "Ter": "Terrace",
            "Trce": "Trace",
            "Trl": "Trail", 
            "Spgs" : ""
            }



def update_name(name, mapping):
    m = street_type_re.search(name)
    if m:
        street_type = m.group()
        if street_type in mapping:
            name = name.replace(street_type, mapping[street_type])

    return name


def shape_element(element):
    node = {"created": {}, "type": 'node', "address": {}, "node_refs": []}
    if element.tag == "node" or element.tag == "way":
        node["type"] = element.tag
        # print element.tag
        # print element.attrib.keys()
        for key in element.attrib.keys():
            if key in CREATED:
                node["created"][key] = element.attrib[key]
            elif key == "lat" or key == "lon":
                node["pos"] = []
                lat = float(element.attrib["lat"])
                lon = float(element.attrib["lon"])
                node["pos"].extend((lat, lon))
            else:
                node[key] = element.attrib[key]

        for child in element:
            if child.tag == "tag":
                if problemchars.search(child.attrib["k"]):
                    continue
                elif child.attrib["k"].startswith("addr:"):
                    addr_attribute = child.attrib["k"].replace("addr:", "")
                    if not lower_colon.search(addr_attribute):
                        if addr_attribute == "full":
                            continue
                        elif addr_attribute == "street":
#                             print addr_attribute
#                             print child.attrib["v"]
#                             print update_name(child.attrib["v"], MAPPING)
                            node["address"][addr_attribute] = update_name(child.attrib["v"], MAPPING)
#                             print node["address"]
                        else:
                            node["address"][addr_attribute] = child.attrib["v"]
#                             print node
                    print node["address"]
                else: 
                    node[child.attrib["k"]] = child.attrib["v"]
            elif child.tag == "nd":
                node["node_refs"].append(child.attrib["ref"])
            else:
                print child.tag, child.attrib

        if not bool(node["address"]):
            node.pop("address", None)
        if not bool(node["node_refs"]):
            node.pop("node_refs", None)

#         print node
        return node
    else:
        return None


def process_map(file_in, pretty=False):
    # You do not need to change this file
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data


def test():
    # NOTE: if you are running this code on your computer, with a larger dataset,
    # call the process_map procedure with pretty=False. The pretty=True option adds
    # additional spaces to the output, making it significantly larger.
    osmfile = "/Users/jpowell/Downloads/data/miami_florida_sample.osm"
    data = process_map(osmfile, False)
    #pprint.pprint(data)


if __name__ == "__main__":
    test()
# Out:
# {'city': 'Miami'}
# {'city': 'Miami', 'street': 'Southwest 78th Place'}
# {'city': 'Miami', 'street': 'Southwest 78th Place', 'postcode': '33144'}
# {'city': 'Delray Beach'}
# {'city': 'Delray Beach', 'state': 'FL'}
# {'city': 'Delray Beach', 'state': 'FL', 'street': 'North Swinton Avenue'}
# {'city': 'Delray Beach', 'state': 'FL', 'street': 'North Swinton Avenue', 'postcode': '33444'}
# {'city': 'Delray Beach', 'state': 'FL', 'street': 'North Swinton Avenue', 'housenumber': '51', 'postcode': '33444'}
# {'city': 'Fort Lauderdale'}
# {'city': 'Fort Lauderdale', 'state': 'FL'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Federal Highway'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Federal Highway', 'postcode': '33308'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Federal Highway', 'housenumber': '4725', 'postcode': '33308'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'city': 'Miami'}
# {'city': 'Miami', 'state': 'FL'}
# {'city': 'Miami', 'state': 'FL', 'street': 'West Flagler Street'}
# {'city': 'Miami', 'state': 'FL', 'street': 'West Flagler Street', 'postcode': '33130'}
# {'city': 'Miami', 'state': 'FL', 'street': 'West Flagler Street', 'housenumber': '101', 'postcode': '33130'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'state': 'FL'}
# {'street': 'Constant Springs Terrace'}
# {'street': 'Constant Springs Terrace', 'housenumber': '5525'}
# {'street': 'Constant Springs Terrace'}
# {'street': 'Constant Springs Terrace', 'housenumber': '5503'}
# {'street': 'Lime Hill Road'}
# {'street': 'Lime Hill Road', 'housenumber': '3427'}
# {'street': 'Dogwood Way'}
# {'street': 'Dogwood Way', 'housenumber': '5506'}
# {'street': 'Lime Hill Road'}
# {'street': 'Lime Hill Road'}
# {'street': 'Lime Hill Road'}
# {'street': 'NW 66th Avenue'}
# {'street': 'NW 66th Avenue', 'housenumber': '1857'}
# {'street': '184th Street'}
# {'street': '184th Street', 'postcode': '33187'}
# {'street': '184th Street', 'housenumber': '16300', 'postcode': '33187'}
# {'street': 'Sunset Drive'}
# {'street': 'Sunset Drive', 'postcode': '33143'}
# {'street': 'Sunset Drive', 'housename': 'City of South Miami City Hall', 'postcode': '33143'}
# {'housenumber': '6130', 'street': 'Sunset Drive', 'housename': 'City of South Miami City Hall', 'postcode': '33143'}
# {'city': 'Miami'}
# {'city': 'Miami', 'street': 'West Flagler Street'}
# {'city': 'Miami', 'street': 'West Flagler Street', 'postcode': '33134'}
# {'city': 'Miami', 'street': 'West Flagler Street', 'housenumber': '4190', 'postcode': '33134'}
# {'street': 'E Atlantic Boulevard'}
# {'street': 'E Atlantic Boulevard', 'postcode': '33060'}
# {'street': 'E Atlantic Boulevard', 'housenumber': '300', 'postcode': '33060'}
# {'street': 'Glades Road'}
# {'street': 'Glades Road', 'housenumber': '9846'}
# {'housenumber': '16351'}
# {'housenumber': '16367'}
# {'street': 'E McNab Road'}
# {'street': 'E McNab Road', 'postcode': '33060'}
# {'street': 'E McNab Road', 'housenumber': '118', 'postcode': '33060'}
# {'street': 'Cordova Avenue'}
# {'street': 'Cordova Avenue', 'postcode': '33316'}
# {'street': 'Cordova Avenue', 'housenumber': '1500', 'postcode': '33316'}
# {'street': 'SW 15th Street'}
# {'street': 'SW 15th Street', 'postcode': '33060'}
# {'street': 'SW 15th Street', 'housenumber': '108', 'postcode': '33060'}
# {'city': 'Miami'}
# {'city': 'Miami', 'street': 'North Bayshore Drive'}
# {'city': 'Miami', 'street': 'North Bayshore Drive', 'country': 'US'}
# {'city': 'Miami', 'street': 'North Bayshore Drive', 'postcode': '33132', 'country': 'US'}
# {'city': 'Miami', 'street': 'North Bayshore Drive', 'housenumber': '1800', 'postcode': '33132', 'country': 'US'}
# {'street': 'Meridian Avenue'}
# {'street': 'Meridian Avenue', 'postcode': '33139'}
# {'street': 'Meridian Avenue', 'housenumber': '407', 'postcode': '33139'}
# {'street': 'Ocean Drive'}
# {'street': 'Ocean Drive', 'postcode': '33139'}
# {'street': 'Ocean Drive', 'housenumber': '1020', 'postcode': '33139'}
# {'city': 'Miami Beach'}
# {'city': 'Miami Beach', 'street': 'Dade Boulevard'}
# {'city': 'Miami Beach', 'street': 'Dade Boulevard', 'postcode': '33139'}
# {'city': 'Miami Beach', 'street': 'Dade Boulevard', 'housenumber': '1045', 'postcode': '33139'}
# {'street': 'Espanola Way'}
# {'street': 'Espanola Way', 'postcode': '33139'}
# {'street': 'Espanola Way', 'housenumber': '218', 'postcode': '33139'}
# {'city': 'Doral'}
# {'city': 'Doral', 'street': 'NW 87th Avenue'}
# {'city': 'Doral', 'street': 'NW 87th Avenue', 'postcode': '33172'}
# {'city': 'Doral', 'street': 'NW 87th Avenue', 'housenumber': '3271 ', 'postcode': '33172'}
# {'postcode': '33029'}
# {'housenumber': '2351', 'postcode': '33029'}
# {'city': 'Fort Lauderdale'}
# {'city': 'Fort Lauderdale', 'street': 'Southeast 16th Street'}
# {'city': 'Fort Lauderdale', 'street': 'Southeast 16th Street', 'postcode': '33316'}
# {'city': 'Fort Lauderdale', 'street': 'Southeast 16th Street', 'housenumber': '1601', 'postcode': '33316'}
# {'city': 'Coral Springs'}
# {'city': 'Coral Springs', 'street': 'West Sample Road'}
# {'city': 'Coral Springs', 'street': 'West Sample Road', 'postcode': '33065'}
# {'city': 'Coral Springs', 'street': 'West Sample Road', 'housenumber': '8650', 'postcode': '33065'}
# {'street': 'Lake Avenue'}
# {'street': 'Lake Avenue', 'postcode': '33460'}
# {'street': 'Lake Avenue', 'housenumber': '921', 'postcode': '33460'}
# {'city': 'Coconut Grove'}
# {'city': 'Coconut Grove', 'street': 'Grand Avenue'}
# {'city': 'Coconut Grove', 'street': 'Grand Avenue', 'postcode': '33133'}
# {'city': 'Coconut Grove', 'street': 'Grand Avenue', 'housenumber': '3111', 'postcode': '33133'}
# {'city': 'Davie'}
# {'city': 'Davie', 'street': '11860 W State Road 84'}
# {'city': 'Davie', 'street': '11860 W State Road 84', 'postcode': '33325'}
# {'city': 'Davie', 'street': '11860 W State Road 84', 'housename': 'Silly Farm Supplies', 'postcode': '33325'}
# {'city': 'Davie', 'street': '11860 W State Road 84', 'housename': 'Silly Farm Supplies', 'postcode': '33325', 'housenumber': 'B1'}
# {'city': 'Miami'}
# {'city': 'Miami', 'street': 'southwest 112th Avenue'}
# {'city': 'Miami', 'street': 'southwest 112th Avenue', 'postcode': '33189'}
# {'city': 'Miami', 'street': 'southwest 112th Avenue', 'housenumber': '20500', 'postcode': '33189'}
# {'city': 'Pinecrest'}
# {'city': 'Pinecrest', 'street': 'South Dixie Highway, Suite 207'}
# {'city': 'Pinecrest', 'street': 'South Dixie Highway, Suite 207', 'postcode': '33157'}
# {'city': 'Pinecrest', 'street': 'South Dixie Highway, Suite 207', 'housename': 'Barnard Law Offices, L.P.', 'postcode': '33157'}
# {'city': 'Pinecrest', 'street': 'South Dixie Highway, Suite 207', 'housename': 'Barnard Law Offices, L.P.', 'postcode': '33157', 'housenumber': '9655'}
# {'city': 'Pompano Beach'}
# {'city': 'Pompano Beach', 'street': 'Beacon Street'}
# {'city': 'Pompano Beach', 'street': 'Beacon Street', 'postcode': '33062'}
# {'city': 'Pompano Beach', 'street': 'Beacon Street', 'housename': 'Dix Family', 'postcode': '33062'}
# {'city': 'Pompano Beach', 'street': 'Beacon Street', 'housename': 'Dix Family', 'postcode': '33062', 'housenumber': '3421'}
# {'city': 'Miami'}
# {'city': 'Miami', 'street': 'Southwest 128th Street'}
# {'city': 'Miami', 'street': 'Southwest 128th Street', 'postcode': '33186'}
# {'city': 'Miami', 'street': 'Southwest 128th Street', 'housename': 'Xtreme Care Body Shop', 'postcode': '33186'}
# {'city': 'Miami', 'street': 'Southwest 128th Street', 'housename': 'Xtreme Care Body Shop', 'postcode': '33186', 'housenumber': '12596'}
# {'city': 'Hialeah'}
# {'city': 'Hialeah', 'street': 'W 49 St Suite 8,9,10'}
# {'city': 'Hialeah', 'street': 'W 49 St Suite 8,9,10', 'postcode': 'FL 33012'}
# {'city': 'Hialeah', 'street': 'W 49 St Suite 8,9,10', 'housenumber': '1738', 'postcode': 'FL 33012'}
# {'city': 'miami Shores'}
# {'city': 'miami Shores', 'street': 'Northeast 96th Street'}
# {'city': 'miami Shores', 'street': 'Northeast 96th Street', 'postcode': '33138'}
# {'city': 'miami Shores', 'street': 'Northeast 96th Street', 'housename': 'Verbena Products', 'postcode': '33138'}
# {'city': 'miami Shores', 'street': 'Northeast 96th Street', 'housename': 'Verbena Products', 'postcode': '33138', 'housenumber': '904'}
# {'city': 'Miami'}
# {'city': 'Miami', 'street': '4427 SW 74 Avenue'}
# {'city': 'Miami', 'street': '4427 SW 74 Avenue', 'postcode': '33155'}
# {'city': 'Palm Beach Gardens'}
# {'city': 'Palm Beach Gardens', 'street': 'Northlake Boulevard'}
# {'city': 'Palm Beach Gardens', 'street': 'Northlake Boulevard', 'housenumber': '3250'}
# {'city': 'Royal Palm Beach'}
# {'city': 'Royal Palm Beach', 'street': 'Misty Oaks Circle'}
# {'city': 'Royal Palm Beach', 'street': 'Misty Oaks Circle', 'housenumber': '2704'}
# {'city': 'Royal Palm Beach'}
# {'city': 'Royal Palm Beach', 'street': 'Misty Oaks Circle'}
# {'city': 'Royal Palm Beach', 'street': 'Misty Oaks Circle', 'housenumber': '2732'}
# {'city': 'Royal Palm Beach'}
# {'city': 'Royal Palm Beach', 'street': 'Misty Oaks Circle'}
# {'city': 'Royal Palm Beach', 'street': 'Misty Oaks Circle', 'housenumber': '2811'}
# {'city': 'West Palm Beach'}
# {'city': 'West Palm Beach', 'street': 'South Rosemary Avenue'}
# {'city': 'West Palm Beach', 'street': 'South Rosemary Avenue', 'postcode': 'FL33401'}
# {'city': 'West Palm Beach', 'street': 'South Rosemary Avenue', 'housenumber': '700', 'postcode': 'FL33401'}
# {'city': 'Miami'}
# {'city': 'Miami', 'state': 'Fl'}
# {'city': 'Miami', 'state': 'Fl', 'street': 'SW 74 Avenue'}
# {'city': 'Miami', 'state': 'Fl', 'street': 'SW 74 Avenue', 'postcode': '33155'}
# {'city': 'Miami', 'state': 'Fl', 'street': 'SW 74 Avenue', 'housenumber': '4615', 'postcode': '33155'}
# {'city': 'Royal Palm Beach'}
# {'city': 'Royal Palm Beach', 'street': 'Misty Oaks Circle'}
# {'city': 'Royal Palm Beach', 'street': 'Misty Oaks Circle', 'housenumber': '2746'}
# {'city': 'Royal Palm Beach'}
# {'city': 'Royal Palm Beach', 'street': 'Misty Oaks Circle'}
# {'city': 'Royal Palm Beach', 'street': 'Misty Oaks Circle', 'housenumber': '2798'}
# {'city': 'Royal Palm Beach'}
# {'city': 'Royal Palm Beach', 'street': 'Misty Oaks Circle'}
# {'city': 'Royal Palm Beach', 'street': 'Misty Oaks Circle', 'housenumber': '2770'}
# {'city': 'Boca Raton'}
# {'city': 'Boca Raton', 'street': 'State Road 7'}
# {'city': 'Boca Raton', 'street': 'State Road 7', 'housename': 'Blue Light IT, LLC'}
# {'city': 'Boca Raton', 'street': 'State Road 7', 'housename': 'Blue Light IT, LLC', 'housenumber': '20283'}
# {'city': 'Miami'}
# {'city': 'Miami', 'street': 'Biscayne Boulevard'}
# {'city': 'Miami', 'street': 'Biscayne Boulevard', 'postcode': '33132'}
# {'city': 'Miami', 'street': 'Biscayne Boulevard', 'housenumber': '990', 'postcode': '33132'}
# {'city': 'Palm Beach'}
# {'city': 'Palm Beach', 'street': 'Worth Avenue'}
# {'city': 'Palm Beach', 'street': 'Worth Avenue', 'housenumber': '250'}
# {'city': 'Miami'}
# {'city': 'Miami', 'state': 'FL'}
# {'city': 'Miami', 'state': 'FL', 'street': 'S Dixie Highway'}
# {'city': 'Miami', 'state': 'FL', 'street': 'S Dixie Highway', 'postcode': '33156'}
# {'city': 'Miami', 'state': 'FL', 'street': 'S Dixie Highway', 'housenumber': '9625', 'postcode': '33156'}
# {'city': 'miami beach'}
# {'city': 'miami beach', 'state': 'FL'}
# {'city': 'miami beach', 'state': 'FL', 'street': 'Lenox Avenue'}
# {'city': 'miami beach', 'state': 'FL', 'street': 'Lenox Avenue', 'postcode': '33139'}
# {'city': 'miami beach', 'state': 'FL', 'street': 'Lenox Avenue', 'housenumber': '1600', 'postcode': '33139'}
# {'city': 'Lake Worth'}
# {'city': 'Lake Worth', 'street': 'Lake Worth Road'}
# {'city': 'Lake Worth', 'street': 'Lake Worth Road', 'postcode': '33461'}
# {'city': 'Lake Worth', 'street': 'Lake Worth Road', 'housenumber': '2745', 'postcode': '33461'}
# {'city': 'Miami'}
# {'city': 'Miami', 'street': 'Northwest 2nd Avenue'}
# {'city': 'Miami', 'street': 'Northwest 2nd Avenue', 'postcode': '33127'}
# {'city': 'Miami', 'street': 'Northwest 2nd Avenue', 'housenumber': '2390', 'postcode': '33127'}
# {'city': 'Miami'}
# {'city': 'Miami', 'street': 'West Flagler Street'}
# {'city': 'Miami', 'street': 'West Flagler Street', 'postcode': '33144'}
# {'city': 'Hollywood'}
# {'city': 'Hollywood', 'street': 'Marina Drive'}
# {'city': 'Hollywood', 'street': 'Marina Drive', 'postcode': '33019'}
# {'city': 'Hollywood', 'street': 'Marina Drive', 'housenumber': '1400', 'postcode': '33019'}
# {'city': 'Aventura'}
# {'city': 'Aventura', 'street': 'Biscayne Boulevard'}
# {'city': 'Aventura', 'street': 'Biscayne Boulevard', 'postcode': '33180'}
# {'city': 'Aventura', 'street': 'Biscayne Boulevard', 'housenumber': '20417', 'postcode': '33180'}
# {'street': 'South Rogers Circle'}
# {'street': 'South Rogers Circle', 'housenumber': '1090'}
# {'street': 'East Rogers Circle'}
# {'street': 'East Rogers Circle', 'housenumber': '6530'}
# {'street': 'East Rogers Circle'}
# {'street': 'East Rogers Circle', 'housenumber': '6630'}
# {'street': 'East Rogers Circle'}
# {'street': 'East Rogers Circle', 'housenumber': '6730'}
# {'street': 'Clint Moore Road'}
# {'street': 'Clint Moore Road', 'housenumber': '912'}
# {'street': 'Clint Moore Road'}
# {'street': 'Clint Moore Road', 'housenumber': '932'}
# {'city': 'Miami Beach'}
# {'city': 'Miami Beach', 'street': 'Lincoln Road'}
# {'city': 'Miami Beach', 'street': 'Lincoln Road', 'housenumber': '1120'}
# {'city': 'Miami'}
# {'city': 'Miami', 'state': 'FL'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Biscayne Boulevard'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Biscayne Boulevard', 'postcode': '33138'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Biscayne Boulevard', 'housenumber': '6730', 'postcode': '33138'}
# {'city': 'Dania Beach'}
# {'city': 'Dania Beach', 'state': 'FL'}
# {'city': 'Dania Beach', 'state': 'FL', 'street': 'East Dania Beach Boulevard'}
# {'city': 'Dania Beach', 'state': 'FL', 'street': 'East Dania Beach Boulevard', 'postcode': '33004'}
# {'city': 'Dania Beach', 'state': 'FL', 'street': 'East Dania Beach Boulevard', 'housenumber': '255', 'postcode': '33004'}
# {'street': 'NW Le Jeune Road'}
# {'street': 'NW Le Jeune Road', 'housenumber': '1201'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'N/A N/A N/A'}
# {'city': 'Weston', 'state': 'FL', 'street': 'N/A N/A N/A', 'suburb': 'N/A'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'N/A N/A N/A', 'suburb': 'N/A'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'N/A', 'state': 'FL', 'street': 'N/A N/A N/A', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'N/A', 'state': 'FL', 'street': 'N/A N/A N/A', 'postcode': '33326', 'housenumber': '0'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Whitehead Circle'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Whitehead Circle', 'suburb': 'Coconuts At Bonaventure'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Whitehead Circle', 'suburb': 'Coconuts At Bonaventure'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Coconuts At Bonaventure', 'state': 'FL', 'street': 'Whitehead Circle', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Coconuts At Bonaventure', 'state': 'FL', 'street': 'Whitehead Circle', 'postcode': '33326', 'housenumber': '10'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Cedar Falls Drive'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Cedar Falls Drive', 'suburb': 'The Falls'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Cedar Falls Drive', 'suburb': 'The Falls'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Falls', 'state': 'FL', 'street': 'Cedar Falls Drive', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Falls', 'state': 'FL', 'street': 'Cedar Falls Drive', 'postcode': '33327', 'housenumber': '1000'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Waterside Circle'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Waterside Circle', 'suburb': 'Savanna'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Waterside Circle', 'suburb': 'Savanna'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Waterside Circle', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Waterside Circle', 'postcode': '33327', 'housenumber': '1000'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Bluewood Terrace'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Bluewood Terrace', 'suburb': 'Savanna'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Bluewood Terrace', 'suburb': 'Savanna'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Bluewood Terrace', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Bluewood Terrace', 'postcode': '33327', 'housenumber': '1002'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Cedar Falls Drive'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Cedar Falls Drive', 'suburb': 'The Falls'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Cedar Falls Drive', 'suburb': 'The Falls'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Falls', 'state': 'FL', 'street': 'Cedar Falls Drive', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Falls', 'state': 'FL', 'street': 'Cedar Falls Drive', 'postcode': '33327', 'housenumber': '1004'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Fairfield Meadows Drive'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Fairfield Meadows Drive', 'suburb': 'The Meadows'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Fairfield Meadows Drive', 'suburb': 'The Meadows'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Meadows', 'state': 'FL', 'street': 'Fairfield Meadows Drive', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Meadows', 'state': 'FL', 'street': 'Fairfield Meadows Drive', 'postcode': '33327', 'housenumber': '1005'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Shadyside Lane'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Shadyside Lane', 'suburb': 'The Meadows'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Shadyside Lane', 'suburb': 'The Meadows'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Meadows', 'state': 'FL', 'street': 'Shadyside Lane', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Meadows', 'state': 'FL', 'street': 'Shadyside Lane', 'postcode': '33327', 'housenumber': '1006'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Spoonbill Circle'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Spoonbill Circle', 'suburb': 'Orchid Island'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Spoonbill Circle', 'suburb': 'Orchid Island'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Orchid Island', 'state': 'FL', 'street': 'Spoonbill Circle', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Orchid Island', 'state': 'FL', 'street': 'Spoonbill Circle', 'postcode': '33326', 'housenumber': '1007'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Cedar Falls Drive'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Cedar Falls Drive', 'suburb': 'The Falls'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Cedar Falls Drive', 'suburb': 'The Falls'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Falls', 'state': 'FL', 'street': 'Cedar Falls Drive', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Falls', 'state': 'FL', 'street': 'Cedar Falls Drive', 'postcode': '33327', 'housenumber': '1009'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Bluewood Terrace'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Bluewood Terrace', 'suburb': 'Savanna'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Bluewood Terrace', 'suburb': 'Savanna'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Bluewood Terrace', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Bluewood Terrace', 'postcode': '33327', 'housenumber': '1010'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Sorrento Drive'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Sorrento Drive', 'suburb': 'San Remo'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Sorrento Drive', 'suburb': 'San Remo'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'San Remo', 'state': 'FL', 'street': 'Sorrento Drive', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'San Remo', 'state': 'FL', 'street': 'Sorrento Drive', 'postcode': '33326', 'housenumber': '1011'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Highland Meadows Drive'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Highland Meadows Drive', 'suburb': 'The Meadows'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Highland Meadows Drive', 'suburb': 'The Meadows'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Meadows', 'state': 'FL', 'street': 'Highland Meadows Drive', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Meadows', 'state': 'FL', 'street': 'Highland Meadows Drive', 'postcode': '33327', 'housenumber': '1012'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Bamboo Lane'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Bamboo Lane', 'suburb': 'Savanna'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Bamboo Lane', 'suburb': 'Savanna'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Bamboo Lane', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Bamboo Lane', 'postcode': '33327', 'housenumber': '1013'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Thistle Creek Court'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Thistle Creek Court', 'suburb': 'The Falls'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Thistle Creek Court', 'suburb': 'The Falls'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Falls', 'state': 'FL', 'street': 'Thistle Creek Court', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Falls', 'state': 'FL', 'street': 'Thistle Creek Court', 'postcode': '33327', 'housenumber': '1014'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Laguna Springs Drive'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Laguna Springs Drive', 'suburb': 'Laguna Springs I'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Laguna Springs Drive', 'suburb': 'Laguna Springs I'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Laguna Springs I', 'state': 'FL', 'street': 'Laguna Springs Drive', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Laguna Springs I', 'state': 'FL', 'street': 'Laguna Springs Drive', 'postcode': '33326', 'housenumber': '1016'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Sunflower Circle'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Sunflower Circle', 'suburb': 'Savanna'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Sunflower Circle', 'suburb': 'Savanna'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Sunflower Circle', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Sunflower Circle', 'postcode': '33327', 'housenumber': '1017'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Thistle Creek Court'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Thistle Creek Court', 'suburb': 'The Falls'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Thistle Creek Court', 'suburb': 'The Falls'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Falls', 'state': 'FL', 'street': 'Thistle Creek Court', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Falls', 'state': 'FL', 'street': 'Thistle Creek Court', 'postcode': '33327', 'housenumber': '1018'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Danielle Court'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Danielle Court', 'suburb': 'Turtle Run'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Danielle Court', 'suburb': 'Turtle Run'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Turtle Run', 'state': 'FL', 'street': 'Danielle Court', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Turtle Run', 'state': 'FL', 'street': 'Danielle Court', 'postcode': '33326', 'housenumber': '102'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Silktree Lane'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Silktree Lane', 'suburb': 'Savanna'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Silktree Lane', 'suburb': 'Savanna'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Silktree Lane', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Silktree Lane', 'postcode': '33327', 'housenumber': '1020'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Creekford Drive'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Creekford Drive', 'suburb': 'Tequesta'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Creekford Drive', 'suburb': 'Tequesta'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Tequesta', 'state': 'FL', 'street': 'Creekford Drive', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Tequesta', 'state': 'FL', 'street': 'Creekford Drive', 'postcode': '33326', 'housenumber': '1022'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Pine Branch Drive'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Pine Branch Drive', 'suburb': 'Tequesta'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Pine Branch Drive', 'suburb': 'Tequesta'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Tequesta', 'state': 'FL', 'street': 'Pine Branch Drive', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Tequesta', 'state': 'FL', 'street': 'Pine Branch Drive', 'postcode': '33326', 'housenumber': '1023'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Pine Branch Court'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Pine Branch Court', 'suburb': 'Tequesta'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Pine Branch Court', 'suburb': 'Tequesta'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Tequesta', 'state': 'FL', 'street': 'Pine Branch Court', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Tequesta', 'state': 'FL', 'street': 'Pine Branch Court', 'postcode': '33326', 'housenumber': '1024'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Laguna Springs Drive'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Laguna Springs Drive', 'suburb': 'Laguna Springs I'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Laguna Springs Drive', 'suburb': 'Laguna Springs I'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Laguna Springs I', 'state': 'FL', 'street': 'Laguna Springs Drive', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Laguna Springs I', 'state': 'FL', 'street': 'Laguna Springs Drive', 'postcode': '33326', 'housenumber': '1025'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Laguna Springs Drive'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Laguna Springs Drive', 'suburb': 'Laguna Springs I'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Laguna Springs Drive', 'suburb': 'Laguna Springs I'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Laguna Springs I', 'state': 'FL', 'street': 'Laguna Springs Drive', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Laguna Springs I', 'state': 'FL', 'street': 'Laguna Springs Drive', 'postcode': '33326', 'housenumber': '1027'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Silktree Lane'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Silktree Lane', 'suburb': 'Savanna'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Silktree Lane', 'suburb': 'Savanna'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Silktree Lane', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Silktree Lane', 'postcode': '33327', 'housenumber': '1028'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Gables Boulevard'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Gables Boulevard', 'country': 'US'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Gables Boulevard', 'postcode': '33326', 'country': 'US'}
# {'city': 'Weston', 'country': 'US', 'state': 'FL', 'street': 'Gables Boulevard', 'postcode': '33326', 'housenumber': '103'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Sunflower Circle'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Sunflower Circle', 'suburb': 'Savanna'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Sunflower Circle', 'suburb': 'Savanna'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Sunflower Circle', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Sunflower Circle', 'postcode': '33327', 'housenumber': '1030'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Cedar Falls Drive'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Cedar Falls Drive', 'suburb': 'The Falls'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Cedar Falls Drive', 'suburb': 'The Falls'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Falls', 'state': 'FL', 'street': 'Cedar Falls Drive', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Falls', 'state': 'FL', 'street': 'Cedar Falls Drive', 'postcode': '33327', 'housenumber': '1032'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Sandalwood Lane'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Sandalwood Lane', 'suburb': 'Tequesta'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Sandalwood Lane', 'suburb': 'Tequesta'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Tequesta', 'state': 'FL', 'street': 'Sandalwood Lane', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Tequesta', 'state': 'FL', 'street': 'Sandalwood Lane', 'postcode': '33326', 'housenumber': '1033'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Briar Ridge Road'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Briar Ridge Road', 'suburb': 'The Falls'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Briar Ridge Road', 'suburb': 'The Falls'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Falls', 'state': 'FL', 'street': 'Briar Ridge Road', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Falls', 'state': 'FL', 'street': 'Briar Ridge Road', 'postcode': '33327', 'housenumber': '1035'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Fairfield Meadows Drive'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Fairfield Meadows Drive', 'suburb': 'The Meadows'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Fairfield Meadows Drive', 'suburb': 'The Meadows'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Meadows', 'state': 'FL', 'street': 'Fairfield Meadows Drive', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Meadows', 'state': 'FL', 'street': 'Fairfield Meadows Drive', 'postcode': '33327', 'housenumber': '1036'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Lido Court'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Lido Court', 'suburb': 'Laguna Springs I'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Lido Court', 'suburb': 'Laguna Springs I'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Laguna Springs I', 'state': 'FL', 'street': 'Lido Court', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Laguna Springs I', 'state': 'FL', 'street': 'Lido Court', 'postcode': '33326', 'housenumber': '1037'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Briar Ridge Road'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Briar Ridge Road', 'suburb': 'The Falls'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Briar Ridge Road', 'suburb': 'The Falls'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Falls', 'state': 'FL', 'street': 'Briar Ridge Road', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Falls', 'state': 'FL', 'street': 'Briar Ridge Road', 'postcode': '33327', 'housenumber': '1039'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Bayside Lane'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Bayside Lane', 'suburb': 'Orchid Island'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Bayside Lane', 'suburb': 'Orchid Island'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Orchid Island', 'state': 'FL', 'street': 'Bayside Lane', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Orchid Island', 'state': 'FL', 'street': 'Bayside Lane', 'postcode': '33326', 'housenumber': '1040'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Spyglass'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Spyglass', 'suburb': 'Laguna Springs I'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Spyglass', 'suburb': 'Laguna Springs I'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Laguna Springs I', 'state': 'FL', 'street': 'Spyglass', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Laguna Springs I', 'state': 'FL', 'street': 'Spyglass', 'postcode': '33326', 'housenumber': '1040'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Thistle Creek Court'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Thistle Creek Court', 'suburb': 'The Falls'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Thistle Creek Court', 'suburb': 'The Falls'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Falls', 'state': 'FL', 'street': 'Thistle Creek Court', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Falls', 'state': 'FL', 'street': 'Thistle Creek Court', 'postcode': '33327', 'housenumber': '1041'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'San Luis Rey'}
# {'city': 'Weston', 'state': 'FL', 'street': 'San Luis Rey', 'suburb': 'Laguna Springs I'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'San Luis Rey', 'suburb': 'Laguna Springs I'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Laguna Springs I', 'state': 'FL', 'street': 'San Luis Rey', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Laguna Springs I', 'state': 'FL', 'street': 'San Luis Rey', 'postcode': '33326', 'housenumber': '1042'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Woodfall Court'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Woodfall Court', 'suburb': 'Tequesta'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Woodfall Court', 'suburb': 'Tequesta'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Tequesta', 'state': 'FL', 'street': 'Woodfall Court', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Tequesta', 'state': 'FL', 'street': 'Woodfall Court', 'postcode': '33326', 'housenumber': '1043'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Spyglass'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Spyglass', 'suburb': 'Laguna Springs I'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Spyglass', 'suburb': 'Laguna Springs I'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Laguna Springs I', 'state': 'FL', 'street': 'Spyglass', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Laguna Springs I', 'state': 'FL', 'street': 'Spyglass', 'postcode': '33326', 'housenumber': '1045'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Tupelo Way'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Tupelo Way', 'suburb': 'Savanna'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Tupelo Way', 'suburb': 'Savanna'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Tupelo Way', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Tupelo Way', 'postcode': '33327', 'housenumber': '1046'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Waterside Circle'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Waterside Circle', 'suburb': 'Savanna'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Waterside Circle', 'suburb': 'Savanna'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Waterside Circle', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Waterside Circle', 'postcode': '33327', 'housenumber': '1047'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Laguna Springs Drive'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Laguna Springs Drive', 'suburb': 'Laguna Springs I'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Laguna Springs Drive', 'suburb': 'Laguna Springs I'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Laguna Springs I', 'state': 'FL', 'street': 'Laguna Springs Drive', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Laguna Springs I', 'state': 'FL', 'street': 'Laguna Springs Drive', 'postcode': '33326', 'housenumber': '1049'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Bayside Lane'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Bayside Lane', 'suburb': 'Orchid Island'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Bayside Lane', 'suburb': 'Orchid Island'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Orchid Island', 'state': 'FL', 'street': 'Bayside Lane', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Orchid Island', 'state': 'FL', 'street': 'Bayside Lane', 'postcode': '33326', 'housenumber': '1050'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Woodfall Court'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Woodfall Court', 'suburb': 'Tequesta'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Woodfall Court', 'suburb': 'Tequesta'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Tequesta', 'state': 'FL', 'street': 'Woodfall Court', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Tequesta', 'state': 'FL', 'street': 'Woodfall Court', 'postcode': '33326', 'housenumber': '1050'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Woodfall Court'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Woodfall Court', 'suburb': 'Tequesta'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Woodfall Court', 'suburb': 'Tequesta'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Tequesta', 'state': 'FL', 'street': 'Woodfall Court', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Tequesta', 'state': 'FL', 'street': 'Woodfall Court', 'postcode': '33326', 'housenumber': '1051'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Nandina Drive'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Nandina Drive', 'suburb': 'Savanna'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Nandina Drive', 'suburb': 'Savanna'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Nandina Drive', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Nandina Drive', 'postcode': '33327', 'housenumber': '1053'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Fairfield Meadows Drive'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Fairfield Meadows Drive', 'suburb': 'The Meadows'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Fairfield Meadows Drive', 'suburb': 'The Meadows'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Meadows', 'state': 'FL', 'street': 'Fairfield Meadows Drive', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Meadows', 'state': 'FL', 'street': 'Fairfield Meadows Drive', 'postcode': '33327', 'housenumber': '1054'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Pine Branch Drive'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Pine Branch Drive', 'suburb': 'Tequesta'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Pine Branch Drive', 'suburb': 'Tequesta'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Tequesta', 'state': 'FL', 'street': 'Pine Branch Drive', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Tequesta', 'state': 'FL', 'street': 'Pine Branch Drive', 'postcode': '33326', 'housenumber': '1055'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Sunflower Circle'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Sunflower Circle', 'suburb': 'Savanna'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Sunflower Circle', 'suburb': 'Savanna'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Sunflower Circle', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Sunflower Circle', 'postcode': '33327', 'housenumber': '1057'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Bluewood Terrace'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Bluewood Terrace', 'suburb': 'Savanna'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Bluewood Terrace', 'suburb': 'Savanna'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Bluewood Terrace', 'postcode': '33327'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Bluewood Terrace', 'postcode': '33327', 'housenumber': '1059'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Cameron Court'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Cameron Court', 'suburb': 'The Lakes'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Cameron Court', 'suburb': 'The Lakes'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Lakes', 'state': 'FL', 'street': 'Cameron Court', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'The Lakes', 'state': 'FL', 'street': 'Cameron Court', 'postcode': '33326', 'housenumber': '106'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Pine Branch Drive'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Pine Branch Drive', 'suburb': 'Tequesta'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Pine Branch Drive', 'suburb': 'Tequesta'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Tequesta', 'state': 'FL', 'street': 'Pine Branch Drive', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Tequesta', 'state': 'FL', 'street': 'Pine Branch Drive', 'postcode': '33326', 'housenumber': '1060'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Pine Branch Drive'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Pine Branch Drive', 'suburb': 'Tequesta'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Pine Branch Drive', 'suburb': 'Tequesta'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Tequesta', 'state': 'FL', 'street': 'Pine Branch Drive', 'postcode': '33326'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Tequesta', 'state': 'FL', 'street': 'Pine Branch Drive', 'postcode': '33326', 'housenumber': '1062'}
# {'city': 'Weston'}
# {'city': 'Weston', 'state': 'FL'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Golden Cane Drive'}
# {'city': 'Weston', 'state': 'FL', 'street': 'Golden Cane Drive', 'suburb': 'Savanna'}
# {'country': 'US', 'city': 'Weston', 'state': 'FL', 'street': 'Golden Cane Drive', 'suburb': 'Savanna'}
# {'city': 'Weston', 'country': 'US', 'suburb': 'Savanna', 'state': 'FL', 'street': 'Golden Cane Drive', 'postcode': '33327'}
# ...
# {'city': 'Miami, Florida'}
# {'city': 'Miami, Florida', 'street': 'Brickell Avenue'}
# {'city': 'Miami, Florida', 'street': 'Brickell Avenue', 'postcode': '33129'}
# {'city': 'Miami, Florida', 'street': 'Brickell Avenue', 'housenumber': '2500', 'postcode': '33129'}
# {'street': 'South Rogers Circle'}
# {'street': 'South Rogers Circle', 'housenumber': '1040'}
# {'city': 'Miami Shores'}
# {'city': 'Miami Shores', 'street': 'Biscayne Boulevard'}
# {'city': 'Miami Shores', 'street': 'Biscayne Boulevard', 'postcode': '33138'}
# {'city': 'Miami Shores', 'street': 'Biscayne Boulevard', 'housenumber': '9020', 'postcode': '33138'}
# {'city': 'Miami Beach'}
# {'city': 'Miami Beach', 'street': 'Collins Avenue'}
# {'city': 'Miami Beach', 'street': 'Collins Avenue', 'postcode': '33154'}
# {'city': 'Miami Beach', 'street': 'Collins Avenue', 'housenumber': '8701', 'postcode': '33154'}
# {'street': 'West Rogers Circle'}
# {'street': 'West Rogers Circle', 'housenumber': '6510'}
# {'city': 'Lake Worth'}
# {'city': 'Lake Worth', 'street': 'N Dixie Highway'}
# {'city': 'Lake Worth', 'street': 'N Dixie Highway', 'postcode': '33460'}
# {'city': 'Lake Worth', 'street': 'N Dixie Highway', 'housenumber': '1532', 'postcode': '33460'}
# {'city': 'Boca Raton'}
# {'city': 'Boca Raton', 'state': 'FL'}
# {'city': 'Boca Raton', 'state': 'FL', 'street': 'Northeast 20th Street'}
# {'city': 'Boca Raton', 'state': 'FL', 'street': 'Northeast 20th Street', 'postcode': '33431'}
# {'city': 'Boca Raton', 'state': 'FL', 'street': 'Northeast 20th Street', 'housenumber': '200', 'postcode': '33431'}
# {'city': 'Delray Beach'}
# {'city': 'Delray Beach', 'street': 'Linton Boulevard'}
# {'city': 'Delray Beach', 'street': 'Linton Boulevard', 'postcode': '33444'}
# {'city': 'Delray Beach', 'street': 'Linton Boulevard', 'housenumber': '900', 'postcode': '33444'}
# {'city': 'Miami Beach'}
# {'city': 'Miami Beach', 'street': '14th Street'}
# {'city': 'Miami Beach', 'street': '14th Street', 'postcode': '33139'}
# {'city': 'Miami Beach', 'street': '14th Street', 'housenumber': '536', 'postcode': '33139'}
# {'city': 'Miami'}
# {'city': 'Miami', 'street': 'South Bayshore Drive'}
# {'city': 'Miami', 'street': 'South Bayshore Drive', 'postcode': '33131'}
# {'city': 'Miami', 'street': 'South Bayshore Drive', 'housenumber': '825', 'postcode': '33131'}
# {'city': 'Miami'}
# {'city': 'Miami', 'street': 'Brickell Avenue'}
# {'city': 'Miami', 'street': 'Brickell Avenue', 'postcode': '33131'}
# {'city': 'Miami', 'street': 'Brickell Avenue', 'housenumber': '1109', 'postcode': '33131'}
# {'city': 'Miami'}
# {'city': 'Miami', 'street': 'Brickell Avenue'}
# {'city': 'Miami', 'street': 'Brickell Avenue', 'postcode': '33131'}
# {'city': 'Miami', 'street': 'Brickell Avenue', 'housenumber': '600', 'postcode': '33131'}
# {'city': 'Miami'}
# {'city': 'Miami', 'street': 'Brickell Avenue'}
# {'city': 'Miami', 'street': 'Brickell Avenue', 'housenumber': '1541'}
# {'city': 'Miami'}
# {'city': 'Miami', 'street': 'Brickell Avenue'}
# {'city': 'Miami', 'street': 'Brickell Avenue', 'housenumber': '2125'}
# {'city': 'Miami'}
# {'city': 'Miami', 'street': 'Brickell Avenue'}
# {'city': 'Miami', 'street': 'Brickell Avenue', 'postcode': '33131'}
# {'city': 'Miami', 'street': 'Brickell Avenue', 'housenumber': '1200', 'postcode': '33131'}
# {'city': 'Miami Beach'}
# {'city': 'Miami Beach', 'street': 'South Pointe Drive'}
# {'city': 'Miami Beach', 'street': 'South Pointe Drive', 'housenumber': '200'}
# {'city': 'Hollywood'}
# {'city': 'Hollywood', 'street': 'Hollywood Boulevard'}
# {'city': 'Hollywood', 'street': 'Hollywood Boulevard', 'housenumber': '3001'}
# {'city': 'Pelican Lake'}
# {'city': 'Pelican Lake', 'street': "Saint Ann's Street"}
# {'city': 'Pelican Lake'}
# {'city': 'Pelican Lake', 'street': 'Pelican Avenue'}
# {'city': 'Pelican Lake'}
# {'city': 'Pelican Lake', 'street': 'Church Street'}
# {'city': 'Pelican Lake'}
# {'city': 'Pelican Lake'}
# {'city': 'Pelican Lake', 'street': 'Hanover Street'}
# {'city': 'Key Biscayne'}
# {'city': 'Key Biscayne', 'street': 'Crandon Boulevard'}
# {'city': 'Key Biscayne', 'street': 'Crandon Boulevard', 'housenumber': '77'}
# {'city': 'Margate'}
# {'city': 'Margate', 'street': 'Southwest 64th Avenue'}
# {'city': 'Margate', 'street': 'Southwest 64th Avenue', 'housenumber': '425'}
# {'city': 'Miami Beach'}
# {'city': 'Miami Beach', 'state': 'FL'}
# {'city': 'Miami Beach', 'state': 'FL', 'street': '71st Street'}
# {'city': 'Miami Beach', 'state': 'FL', 'street': '71st Street', 'postcode': '33141'}
# {'city': 'Miami Beach', 'state': 'FL', 'street': '71st Street', 'housenumber': '500', 'postcode': '33141'}
# {'city': 'Miami Beach'}
# {'city': 'Miami Beach', 'state': 'FL'}
# {'city': 'Miami Beach', 'state': 'FL', 'street': '71st Street'}
# {'city': 'Miami Beach', 'state': 'FL', 'street': '71st Street', 'housenumber': '414'}
# {'city': 'Miami'}
# {'city': 'Miami', 'state': 'FL'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Biscayne Boulevard'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Biscayne Boulevard', 'postcode': '33137'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Biscayne Boulevard', 'housenumber': '4800', 'postcode': '33137'}
# {'city': 'Miami'}
# {'city': 'Miami', 'state': 'FL'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Northeast 18th Street'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Northeast 18th Street', 'housenumber': '210'}
# {'city': 'Doral'}
# {'city': 'Doral', 'state': 'FL'}
# {'city': 'Doral', 'state': 'FL', 'street': 'Northwest 112th Avenue'}
# {'city': 'Doral', 'state': 'FL', 'street': 'Northwest 112th Avenue', 'postcode': '33178'}
# {'city': 'Doral', 'state': 'FL', 'street': 'Northwest 112th Avenue', 'housenumber': '5215', 'postcode': '33178'}
# {'city': 'Key Biscayne'}
# {'city': 'Key Biscayne', 'state': 'FL'}
# {'city': 'Key Biscayne', 'state': 'FL', 'street': 'Crandon Boulevard'}
# {'city': 'Key Biscayne', 'state': 'FL', 'street': 'Crandon Boulevard', 'housenumber': '789'}
# {'city': 'Doral'}
# {'city': 'Doral', 'state': 'FL'}
# {'city': 'Doral', 'state': 'FL', 'street': 'Northwest 109th Avenue'}
# {'city': 'Doral', 'state': 'FL', 'street': 'Northwest 109th Avenue', 'postcode': '33178'}
# {'city': 'Doral', 'state': 'FL', 'street': 'Northwest 109th Avenue', 'housenumber': '5240', 'postcode': '33178'}
# {'city': 'Miami'}
# {'city': 'Miami', 'state': 'FL'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Northwest 54th Street'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Northwest 54th Street', 'postcode': '33127'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Northwest 54th Street', 'housenumber': '294', 'postcode': '33127'}
# {'city': 'Fort Lauderdale'}
# {'city': 'Fort Lauderdale', 'state': 'FL'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Federal Highway'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Federal Highway', 'postcode': '33304'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Federal Highway', 'housenumber': '1615', 'postcode': '33304'}
# {'city': 'Fort Lauderdale'}
# {'city': 'Fort Lauderdale', 'state': 'FL'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Federal Highway'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Federal Highway', 'postcode': '33304'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Federal Highway', 'housenumber': '2309', 'postcode': '33304'}
# {'city': 'Fort Lauderdale'}
# {'city': 'Fort Lauderdale', 'state': 'FL'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Federal Highway'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Federal Highway', 'postcode': '33308'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Federal Highway', 'housenumber': '5000', 'postcode': '33308'}
# {'city': 'Opa-locka'}
# {'city': 'Opa-locka', 'state': 'FL'}
# {'city': 'Opa-locka', 'state': 'FL', 'street': 'Ali Baba Avenue'}
# {'city': 'Opa-locka', 'state': 'FL', 'street': 'Ali Baba Avenue', 'housenumber': '675'}
# {'city': 'Fort Lauderdale'}
# {'city': 'Fort Lauderdale', 'state': 'FL'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Sunrise Boulevard'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Sunrise Boulevard', 'postcode': '33304'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Sunrise Boulevard', 'housenumber': '1415', 'postcode': '33304'}
# {'city': 'Lauderhill'}
# {'city': 'Lauderhill', 'state': 'FL'}
# {'city': 'Lauderhill', 'state': 'FL', 'street': 'West Commercial Boulevard'}
# {'city': 'Lauderhill', 'state': 'FL', 'street': 'West Commercial Boulevard', 'postcode': '33319'}
# {'city': 'Lauderhill', 'state': 'FL', 'street': 'West Commercial Boulevard', 'housenumber': '6980', 'postcode': '33319'}
# {'city': 'Plantation'}
# {'city': 'Plantation', 'state': 'FL'}
# {'city': 'Plantation', 'state': 'FL', 'street': 'Northwest 107th Terrace'}
# {'city': 'Plantation', 'state': 'FL', 'street': 'Northwest 107th Terrace', 'postcode': '33322'}
# {'city': 'Plantation', 'state': 'FL', 'street': 'Northwest 107th Terrace', 'housenumber': '1701', 'postcode': '33322'}
# {'city': 'Miami'}
# {'city': 'Miami', 'state': 'FL'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Biscayne Boulevard'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Biscayne Boulevard', 'housenumber': '1103'}
# {'city': 'Dania Beach'}
# {'city': 'Dania Beach', 'state': 'FL'}
# {'city': 'Dania Beach', 'state': 'FL', 'street': 'Southwest 18th Court'}
# {'city': 'Dania Beach', 'state': 'FL', 'street': 'Southwest 18th Court', 'postcode': '33004'}
# {'city': 'Dania Beach', 'state': 'FL', 'street': 'Southwest 18th Court', 'housenumber': '151', 'postcode': '33004'}
# {'city': 'Fort Lauderdale'}
# {'city': 'Fort Lauderdale', 'state': 'FL'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Orton Avenue'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Orton Avenue', 'postcode': '33304'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Orton Avenue', 'housenumber': '700', 'postcode': '33304'}
# {'city': 'Fort Lauderdale'}
# {'city': 'Fort Lauderdale', 'state': 'FL'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Terramar Street'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Terramar Street', 'postcode': '33304'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Terramar Street', 'housenumber': '2800', 'postcode': '33304'}
# {'city': 'Fort Lauderdale'}
# {'city': 'Fort Lauderdale', 'state': 'FL'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Orton Avenue'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Orton Avenue', 'postcode': '33304'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'Orton Avenue', 'housenumber': '606', 'postcode': '33304'}
# {'city': 'Fort Lauderdale'}
# {'city': 'Fort Lauderdale', 'state': 'FL'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'North Birch Road'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'North Birch Road', 'postcode': '33304'}
# {'city': 'Fort Lauderdale', 'state': 'FL', 'street': 'North Birch Road', 'housenumber': '552', 'postcode': '33304'}
# {'city': 'Miami'}
# {'city': 'Miami', 'state': 'FL'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Southwest 8th Street'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Southwest 8th Street', 'housenumber': '1508'}
# {'city': 'Boca Raton'}
# {'city': 'Boca Raton', 'state': 'FL'}
# {'city': 'Boca Raton', 'state': 'FL', 'street': 'Yamato Road'}
# {'city': 'Boca Raton', 'state': 'FL', 'street': 'Yamato Road', 'postcode': '33431'}
# {'city': 'Boca Raton', 'state': 'FL', 'street': 'Yamato Road', 'housenumber': '1499', 'postcode': '33431'}
# {'city': 'Miami'}
# {'city': 'Miami', 'state': 'FL'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Blue Lagoon Drive'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Blue Lagoon Drive', 'postcode': '33126'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Blue Lagoon Drive', 'housenumber': '5505', 'postcode': '33126'}
# {'city': 'Miami'}
# {'city': 'Miami', 'postcode': '33146'}
# {'city': 'Boca Raton'}
# {'city': 'Boca Raton', 'state': 'FL'}
# {'city': 'Boca Raton', 'state': 'FL', 'street': 'Northeast 20th Street'}
# {'city': 'Boca Raton', 'state': 'FL', 'street': 'Northeast 20th Street', 'postcode': '33431'}
# {'city': 'Boca Raton', 'state': 'FL', 'street': 'Northeast 20th Street', 'housenumber': '200', 'postcode': '33431'}
# {'street': 'Northwest 75th Court'}
# {'street': 'Northwest 75th Court', 'housenumber': '8686'}
# {'city': 'Wellington'}
# {'city': 'Wellington', 'state': 'FL'}
# {'city': 'Wellington', 'state': 'FL', 'street': 'Wellington Green Drive'}
# {'city': 'Wellington', 'state': 'FL', 'street': 'Wellington Green Drive', 'housenumber': '2175'}
# {'city': 'North Palm Beach'}
# {'city': 'North Palm Beach', 'state': 'FL'}
# {'city': 'North Palm Beach', 'state': 'FL', 'postcode': '33408'}
# {'city': 'Miami'}
# {'city': 'Miami', 'state': 'FL'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Northeast 167th Street'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Northeast 167th Street', 'country': 'US'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Northeast 167th Street', 'postcode': '33162', 'country': 'US'}
# {'city': 'Miami', 'country': 'US', 'state': 'FL', 'street': 'Northeast 167th Street', 'postcode': '33162', 'housenumber': '120'}
# {'city': 'Lake Worth'}
# {'city': 'Lake Worth', 'state': 'FL'}
# {'city': 'Lake Worth', 'state': 'FL', 'street': 'Grand Lacuna Boulevard'}
# {'city': 'Lake Worth', 'state': 'FL', 'street': 'Grand Lacuna Boulevard', 'postcode': '33467'}
# {'city': 'Lake Worth', 'state': 'FL', 'street': 'Grand Lacuna Boulevard', 'housenumber': '6400', 'postcode': '33467'}
# {'city': 'Lake Worth'}
# {'city': 'Lake Worth', 'state': 'FL'}
# {'city': 'Lake Worth', 'state': 'FL', 'street': 'Lake Worth Road'}
# {'city': 'Lake Worth', 'state': 'FL', 'street': 'Lake Worth Road', 'housenumber': '8401'}
# {'street': 'Wellington Parc Drive'}
# {'interpolation': 'odd'}
# {'city': 'Miramar'}
# {'city': 'Miramar', 'state': 'F'}
# {'city': 'Miramar', 'state': 'F', 'street': 'SW 145th Avenue'}
# {'city': 'Miramar', 'state': 'F', 'street': 'SW 145th Avenue', 'postcode': '33027'}
# {'city': 'Miramar', 'state': 'F', 'street': 'SW 145th Avenue', 'housenumber': '1930', 'postcode': '33027'}
# {'city': 'Wellington'}
# {'city': 'Wellington', 'street': 'Flying Cow Ranch Road'}
# {'city': 'Wellington', 'street': 'Flying Cow Ranch Road', 'postcode': '33414'}
# {'city': 'Wellington', 'street': 'Flying Cow Ranch Road', 'housenumber': '4499', 'postcode': '33414'}
# {'city': 'coral springs'}
# {'city': 'coral springs', 'state': 'Florida'}
# {'city': 'coral springs', 'state': 'Florida', 'street': 'Northwest 44th Street'}
# {'city': 'coral springs', 'state': 'Florida', 'street': 'Northwest 44th Street', 'postcode': '33065'}
# {'city': 'coral springs', 'state': 'Florida', 'street': 'Northwest 44th Street', 'housenumber': '12477', 'postcode': '33065'}
# {'city': 'Coral Gables'}
# {'city': 'Coral Gables', 'state': 'FL'}
# {'city': 'Coral Gables', 'state': 'FL', 'street': 'Theo Dickenson Drive'}
# {'city': 'Coral Gables', 'state': 'FL', 'street': 'Theo Dickenson Drive', 'postcode': '33146'}
# {'city': 'Coral Gables', 'state': 'FL', 'street': 'Theo Dickenson Drive', 'housenumber': '1231', 'postcode': '33146'}
# {'city': 'Miami'}
# {'city': 'Miami', 'state': 'FL'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Southwest 104th Street'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Southwest 104th Street', 'postcode': '33196'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Southwest 104th Street', 'housenumber': '15024', 'postcode': '33196'}
# {'street': 'East Sample Road'}
# {'street': 'East Sample Road', 'housenumber': '1501'}
# {'city': 'Miami Beach'}
# {'city': 'Miami Beach', 'state': 'FL'}
# {'city': 'Miami Beach', 'state': 'FL', 'street': 'Pinetree Drive'}
# {'city': 'Miami Beach', 'state': 'FL', 'street': 'Pinetree Drive', 'postcode': '33140'}
# {'city': 'Miami Beach', 'state': 'FL', 'street': 'Pinetree Drive', 'housenumber': '2401', 'postcode': '33140'}
# {'city': 'Miami'}
# {'city': 'Miami', 'state': 'FL'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Ocean Drive'}
# {'city': 'Miami', 'state': 'FL', 'street': 'Ocean Drive', 'housenumber': '530'}
# {'city': 'Miami Beach'}
# {'city': 'Miami Beach', 'state': 'FL'}
# {'city': 'Miami Beach', 'state': 'FL', 'street': 'Collins Avenue'}
# {'city': 'Miami Beach', 'state': 'FL', 'street': 'Collins Avenue', 'housenumber': '1700'}

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import xml.etree.ElementTree as ET  # Use cElementTree or lxml if too slow

# OSM_FILE = "osm_file.osm"  # Replace this with your osm file
OSM_FILE = "/Users/jpowell/Downloads/data/miami_florida.osm"
SAMPLE_FILE = "/Users/jpowell/Downloads/data/miami_florida_sample.osm"


def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every 10th top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % 10 == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')
