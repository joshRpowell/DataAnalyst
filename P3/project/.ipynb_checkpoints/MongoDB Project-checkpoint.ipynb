# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
"""
Your task is to use the iterative parsing to process the map file and
find out not only what tags are there, but also how many, to get the
feeling on how much of which data you can expect to have in the map.
Fill out the count_tags function. It should return a dictionary with the
tag name as the key and number of times this tag can be encountered in
the map as value.

Note that your code will be tested with a different data file than the 'example.osm'
"""
import xml.etree.cElementTree as ET
import pprint


def count_tags(filename):
    d = {}
    for event, elem in ET.iterparse(filename):
        if elem.tag in d:
            d[elem.tag] += 1
        else:
            d[elem.tag] = 1
            
    return d


def test():
    osm_file = open("/Users/jpowell/Downloads/data/miami_florida.osm", "r")

    tags = count_tags(osm_file)
    pprint.pprint(tags)

if __name__ == "__main__":
    test()
# Out:
# {'bounds': 1,
#  'member': 42426,
#  'nd': 1807642,
#  'node': 1516787,
#  'osm': 1,
#  'relation': 1523,
#  'tag': 1477841,
#  'way': 198244}

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.cElementTree as ET
import pprint
import re
"""
Your task is to explore the data a bit more.
Before you process the data and add it into MongoDB, you should
check the "k" value for each "<tag>" and see if they can be valid keys in MongoDB,
as well as see if there are any other potential problems.

We have provided you with 3 regular expressions to check for certain patterns
in the tags. As we saw in the quiz earlier, we would like to change the data model
and expand the "addr:street" type of keys to a dictionary like this:
{"address": {"street": "Some value"}}
So, we have to see if we have such tags, and if we have any tags with problematic characters.
Please complete the function 'key_type'.
"""


lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
upper = re.compile(r'^([A-Z]|_)*$')
upper_colon = re.compile(r'^([A-Z]|_)*:([A-Z]|_)*$')
lower_upper_colon = re.compile(r'^([a-z]|_)*:([A-Z]|_)*$')

problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    if element.tag == "tag":
        for tag in element.iter("tag"):
            value = tag.attrib['k'] 
            if lower.search(value):
                keys['lower'] += 1
#                 print 'lower'
#                 print value
            elif lower_colon.search(value):
                keys['lower_colon'] += 1
#                 print 'lower_colon'
#                 print value
            elif upper.search(value):
                keys['upper'] += 1
#                 print 'lower'
#                 print value
            elif upper_colon.search(value):
                keys['upper_colon'] += 1
#                 print 'lower_colon'
#                 print value
            elif lower_upper_colon.search(value):
                keys['lower_upper_colon'] += 1
#                 print 'lower_colon'
#                 print value
            elif problemchars.search(value):
                keys['problemchars'] += 1
                print 'problemchars'
                print value
            else:
                keys['other'] += 1
#                 print 'other'
#                 print value

    return keys


def count_tags(element, dictionary):
    if element.tag == "tag":
        for tag in element.iter("tag"):
            value = tag.attrib["k"]
            # print elem.tag
            if value in dictionary:
                dictionary[value] += 1
            else:
                dictionary[value] = 1
        # print pprint.pprint(d)
    return dictionary


def process_map(filename):
    d = {}
    keys = {"lower": 0, "lower_colon": 0, "upper": 0, "upper_colon": 0, "lower_upper_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)
        d = count_tags(element, d)

    return keys, d


def test():
    # You can use another testfile 'map.osm' to look at your solution
    # Note that the assertions will be incorrect then.
    osm_file = open("/Users/jpowell/Downloads/data/miami_florida.osm", "r")

    keys = process_map(osm_file)
    pprint.pprint(keys)
    

if __name__ == "__main__":
    test()
# Out:
# problemchars
# Gourmet Foods
# problemchars
# Moving From
# ({'lower': 602295,
#   'lower_colon': 829057,
#   'lower_upper_colon': 2406,
#   'other': 28768,
#   'problemchars': 2,
#   'upper': 15198,
#   'upper_colon': 115},
#  {'Company': 1,
#   'FCC_ASR_Reg': 2,
#   'FIXME': 1528,
#   'FIXME:aeroway': 1,
#   'FIXME:amenity': 10,
#   'FIXME:building': 2,
#   'FIXME:construction': 7,
#   'FIXME:cycleway': 23,
#   'FIXME:depth': 4,
#   'FIXME:hgv': 39,
#   'FIXME:highway': 6,
#   'FIXME:lanes': 9,
#   'FIXME:lcn_ref': 1,
#   'FIXME:maxspeed': 193,
#   'FIXME:name': 38,
#   'FIXME:old_ref:1945': 40,
#   'FIXME:old_ref:pre_1945': 4,
#   'Gourmet Foods': 1,
#   'HFCS': 11196,
#   'ISO3166-1': 1,
#   'ISO3166-1:alpha2': 1,
#   'ISO3166-1:alpha3': 1,
#   'ISO3166-1:numeric': 1,
#   'ISO3166-2': 1,
#   'Moving From': 1,
#   'NHD:ComID': 103,
#   'NHD:FCode': 103,
#   'NHD:FDate': 12,
#   'NHD:FTYPE': 12,
#   'NHD:FType': 91,
#   'NHD:Permanent_': 12,
#   'NHD:RESOLUTION': 103,
#   'NHD:ReachCode': 88,
#   'NHD:way_id': 91,
#   'NHS': 2473,
#   'PKSCHOOL': 1,
#   'abandoned:building': 1,
#   'access': 4409,
#   'addr:city': 20011,
#   'addr:country': 18304,
#   'addr:floor': 1,
#   'addr:full': 18244,
#   'addr:housename': 82,
#   'addr:housenumber': 20311,
#   'addr:interpolation': 17,
#   'addr:postcode': 19615,
#   'addr:province': 2,
#   'addr:source': 2,
#   'addr:state': 20683,
#   'addr:street': 20445,
#   'addr:suburb': 17254,
#   'addr:suite': 1,
#   'addr:unit': 6,
#   'address': 1,
#   'admin_level': 441,
#   'aerialway': 3,
#   'aerodrome': 1,
#   'aeroway': 1741,
#   'alt_name': 857,
#   'alt_name:vi': 1,
#   'alt_name_1': 1,
#   'alt_ref': 12,
#   'amenity': 9135,
#   'amenity_1': 1,
#   'area': 894,
#   'area:highway': 1,
#   'artist_name': 7,
#   'artwork_type': 9,
#   'atm': 122,
#   'attraction': 84,
#   'attribution': 93,
#   'backrest': 38,
#   'bar': 1,
#   'barrier': 1948,
#   'beach': 3,
#   'bench': 18,
#   'bicycle': 3879,
#   'bicycle:lanes': 1,
#   'bicycle_parking': 16,
#   'bin': 2,
#   'board_type': 1,
#   'boat': 69,
#   'border_type': 352,
#   'boundary': 640,
#   'boundary_type': 3,
#   'brand': 48,
#   'bridge': 3406,
#   'bridge:movable': 2,
#   'bridge:structure': 3,
#   'building': 34839,
#   'building:colour': 37,
#   'building:height': 1,
#   'building:levels': 406,
#   'building:material': 12,
#   'building:part': 56,
#   'building:type': 2,
#   'building:use': 18,
#   'building_1': 1,
#   'bus': 65,
#   'button_operated': 1,
#   'cables': 536,
#   'capacity': 38,
#   'capacity:disabled': 5,
#   'car_wash': 2,
#   'census:population': 93,
#   'centre_turn_lane': 126,
#   'circuits': 435,
#   'clothes': 1,
#   'collection_times': 2,
#   'colour': 168,
#   'communication:mobile_phone': 1,
#   'constr': 1,
#   'construction': 276,
#   'construction:lanes': 43,
#   'contact:email': 2,
#   'contact:facebook': 1,
#   'contact:google_plus': 1,
#   'contact:phone': 9,
#   'contact:twitter': 1,
#   'contact:website': 5,
#   'county_id': 1,
#   'courts': 1,
#   'covered': 137,
#   'craft': 4,
#   'created_by': 296,
#   'crossing': 930,
#   'crossing:barrier': 4,
#   'crossing:bell': 2,
#   'crossing:light': 2,
#   'crossing_ref': 6,
#   'cuisine': 530,
#   'cuisine_1': 1,
#   'cutting': 40,
#   'cycle_network': 10,
#   'cyclerating': 2,
#   'cycleway': 1737,
#   'cycleway:left': 6,
#   'cycleway:right': 54,
#   'deep_draft': 33,
#   'delivery': 12,
#   'demolished:highway': 32,
#   'demolished:man_made': 1,
#   'demolished:power': 1,
#   'denomination': 275,
#   'denotation': 65,
#   'depth': 40,
#   'description': 80,
#   'description:en': 1,
#   'design': 129,
#   'designation': 18,
#   'destination': 308,
#   'destination:forward': 4,
#   'destination:lanes': 10,
#   'destination:ref': 174,
#   'diet': 1,
#   'direction': 44,
#   'direction_east': 4,
#   'direction_north': 10,
#   'direction_south': 2,
#   'direction_west': 7,
#   'dispensing': 13,
#   'dist:blue': 28,
#   'dist:gold': 27,
#   'dist:red': 28,
#   'dist:white': 28,
#   'disused': 33,
#   'disused:aeroway': 1,
#   'disused:amenity': 1,
#   'disused:highway': 12,
#   'disused:leisure': 3,
#   'dog': 2,
#   'drinking_water': 8,
#   'drinking_water:legal': 2,
#   'drive_in': 2,
#   'drive_through': 26,
#   'ele': 5576,
#   'electrified': 388,
#   'email': 12,
#   'embankment': 438,
#   'emergency': 113,
#   'end_date': 1,
#   'entrance': 116,
#   'est_width': 8,
#   'except': 2,
#   'exit_to': 108,
#   'faa': 2,
#   'fax': 11,
#   'fcc_reg': 1,
#   'fdot:fihs': 2119,
#   'fdot:ref': 3,
#   'fdot:sis': 2496,
#   'fee': 154,
#   'female': 2,
#   'fence': 1,
#   'fence_type': 50,
#   'fenced': 1,
#   'finely_mown': 35,
#   'fire_hydrant:type': 32,
#   'fireplace': 5,
#   'fixme': 150,
#   'flag': 1,
#   'food': 2,
#   'foot': 3715,
#   'footway': 566,
#   'frequency': 838,
#   'from': 8,
#   'fuel:diesel': 2,
#   'fuel:octane_91': 1,
#   'gauge': 313,
#   'generator:output:electricity': 1,
#   'generator:source': 2,
#   'gluten_free': 1,
#   'gnis:Class': 489,
#   'gnis:County': 489,
#   'gnis:County_num': 489,
#   'gnis:ST_alpha': 489,
#   'gnis:ST_num': 489,
#   'gnis:county_id': 3416,
#   'gnis:county_name': 1645,
#   'gnis:created': 3532,
#   'gnis:edited': 23,
#   'gnis:feature_id': 5137,
#   'gnis:feature_type': 117,
#   'gnis:id': 489,
#   'gnis:import_uuid': 1524,
#   'gnis:reviewed': 1522,
#   'gnis:state_id': 3416,
#   'golf': 1516,
#   'golf:course': 39,
#   'golf:designer': 4,
#   'golf:par': 39,
#   'golf_cart': 9,
#   'gtfs_id': 8342,
#   'gtfs_route_color': 106,
#   'gtfs_route_id': 106,
#   'gtfs_route_long_name': 106,
#   'gtfs_route_short_name': 106,
#   'gtfs_route_text_color': 106,
#   'gtfs_route_type': 106,
#   'guidepost': 6,
#   'handicap': 74,
#   'handrail': 1,
#   'harbour': 1,
#   'harbour:electricity': 1,
#   'harbour:fuel_station': 1,
#   'harbour:laundrette': 1,
#   'harbour:showers': 1,
#   'harbour:water_tap': 1,
#   'hazard:bicycle': 31,
#   'height': 104,
#   'height_agl_m': 2,
#   'heritage': 1,
#   'heritage:operator': 1,
#   'hgv': 6781,
#   'hgv:national_network': 441,
#   'hgv:tandem': 39,
#   'highway': 161302,
#   'highway:demolished': 2,
#   'historic': 31,
#   'history': 11,
#   'hoops': 14,
#   'horizontal_bar': 1,
#   'horse': 3273,
#   'hotel': 1,
#   'hov': 522,
#   'ht_agl_m': 2,
#   'iata': 10,
#   'icao': 8,
#   'image': 26,
#   'import_uuid': 491,
#   'incline': 15,
#   'incorporation_type': 197,
#   'indoor': 3,
#   'information': 98,
#   'intermittent': 118,
#   'internet_access': 28,
#   'internet_access:fee': 5,
#   'is_in': 688,
#   'is_in:city': 1,
#   'is_in:continent': 2,
#   'is_in:country': 187,
#   'is_in:country_code': 187,
#   'is_in:iso_3166_2': 185,
#   'is_in:state': 297,
#   'is_in:state_code': 185,
#   'is_in:theme_park': 20,
#   'iucn_level': 1,
#   'junction': 530,
#   'kayak': 2,
#   'landuse': 2780,
#   'lanes': 16621,
#   'lanes:backward': 6,
#   'lanes:forward': 9,
#   'layer': 2153,
#   'lcn': 175,
#   'lcn_ref': 66,
#   'leaf_type': 60,
#   'leisure': 4403,
#   'length': 9,
#   'length_ft': 3,
#   'length_m': 3,
#   'length_unit': 1,
#   'level': 15,
#   'light_rail': 1,
#   'line': 37,
#   'lit': 215,
#   'loc_name': 1,
#   'location': 274,
#   'male': 2,
#   'man_made': 1777,
#   'map_size': 2,
#   'maritime': 2,
#   'material': 171,
#   'materialt': 1,
#   'maxheight': 10,
#   'maxspeed': 7000,
#   'maxspeed:backward': 171,
#   'maxspeed:forward': 171,
#   'maxstay': 1,
#   'maze': 1,
#   'microbrewery': 4,
#   'monitoring_station': 1,
#   'mooring': 1,
#   'motor_vehicle': 275,
#   'motorcar': 9,
#   'motorcycle': 6,
#   'mown': 39,
#   'mtb:scale': 2,
#   'mtb:scale:imba': 3,
#   'name': 116840,
#   'name:ab': 1,
#   'name:ace': 1,
#   'name:af': 1,
#   'name:als': 1,
#   'name:am': 1,
#   'name:an': 1,
#   'name:ang': 1,
#   'name:ar': 2,
#   'name:arc': 1,
#   'name:arz': 1,
#   'name:as': 1,
#   'name:ast': 1,
#   'name:av': 1,
#   'name:ay': 1,
#   'name:az': 1,
#   'name:ba': 1,
#   'name:bar': 1,
#   'name:bat-smg': 1,
#   'name:bcl': 1,
#   'name:be': 2,
#   'name:be-x-old': 1,
#   'name:bg': 1,
#   'name:bi': 1,
#   'name:bm': 1,
#   'name:bn': 1,
#   'name:bo': 1,
#   'name:botanical': 19,
#   'name:bpy': 1,
#   'name:br': 1,
#   'name:bs': 1,
#   'name:bxr': 1,
#   'name:ca': 1,
#   'name:cbk-zam': 1,
#   'name:cdo': 1,
#   'name:ce': 1,
#   'name:ceb': 1,
#   'name:chr': 1,
#   'name:chy': 1,
#   'name:ckb': 1,
#   'name:co': 1,
#   'name:crh': 1,
#   'name:cs': 1,
#   'name:csb': 1,
#   'name:cu': 1,
#   'name:cv': 1,
#   'name:cy': 1,
#   'name:da': 1,
#   'name:de': 11,
#   'name:diq': 1,
#   'name:dsb': 1,
#   'name:dv': 1,
#   'name:dz': 1,
#   'name:ee': 1,
#   'name:el': 2,
#   'name:eml': 1,
#   'name:en': 14,
#   'name:eo': 2,
#   'name:es': 4,
#   'name:et': 1,
#   'name:eu': 1,
#   'name:ext': 1,
#   'name:fa': 2,
#   'name:ff': 1,
#   'name:fi': 1,
#   'name:fiu-vro': 1,
#   'name:fo': 1,
#   'name:fr': 7,
#   'name:frp': 1,
#   'name:frr': 1,
#   'name:fur': 1,
#   'name:fy': 1,
#   'name:ga': 1,
#   'name:gag': 1,
#   'name:gan': 1,
#   'name:gd': 1,
#   'name:gl': 1,
#   'name:glk': 1,
#   'name:gn': 1,
#   'name:gu': 1,
#   'name:gv': 1,
#   'name:ha': 1,
#   'name:hak': 1,
#   'name:haw': 2,
#   'name:he': 2,
#   'name:hi': 1,
#   'name:hif': 1,
#   'name:hr': 1,
#   'name:hsb': 1,
#   'name:ht': 1,
#   'name:hu': 1,
#   'name:hy': 2,
#   'name:ia': 1,
#   'name:id': 1,
#   'name:ie': 1,
#   'name:ig': 1,
#   'name:ik': 1,
#   'name:ilo': 1,
#   'name:io': 1,
#   'name:is': 2,
#   'name:it': 3,
#   'name:iu': 1,
#   'name:ja': 2,
#   'name:jbo': 1,
#   'name:jv': 1,
#   'name:ka': 2,
#   'name:kaa': 1,
#   'name:kab': 1,
#   'name:kbd': 1,
#   'name:ki': 1,
#   'name:kk': 1,
#   'name:kl': 1,
#   'name:km': 1,
#   'name:kn': 1,
#   'name:ko': 2,
#   'name:koi': 1,
#   'name:krc': 1,
#   'name:ks': 1,
#   'name:ksh': 1,
#   'name:ku': 1,
#   'name:kv': 1,
#   'name:kw': 1,
#   'name:ky': 1,
#   'name:la': 2,
#   'name:lad': 1,
#   'name:lb': 1,
#   'name:lbe': 1,
#   'name:lez': 1,
#   'name:lg': 1,
#   'name:li': 1,
#   'name:lij': 1,
#   'name:lmo': 1,
#   'name:ln': 1,
#   'name:lo': 1,
#   'name:lt': 3,
#   'name:ltg': 1,
#   'name:lv': 1,
#   'name:map-bms': 1,
#   'name:mdf': 1,
#   'name:mg': 1,
#   'name:mhr': 1,
#   'name:mi': 1,
#   'name:min': 1,
#   'name:mk': 1,
#   'name:ml': 1,
#   'name:mn': 1,
#   'name:mr': 1,
#   'name:mrj': 1,
#   'name:ms': 1,
#   'name:mt': 1,
#   'name:mwl': 1,
#   'name:my': 1,
#   'name:myv': 1,
#   'name:mzn': 1,
#   'name:na': 1,
#   'name:nah': 1,
#   'name:nap': 1,
#   'name:nds': 1,
#   'name:nds-nl': 1,
#   'name:ne': 1,
#   'name:new': 1,
#   'name:nl': 2,
#   'name:nn': 1,
#   'name:no': 1,
#   'name:nov': 1,
#   'name:nrm': 1,
#   'name:nso': 1,
#   'name:nv': 2,
#   'name:oc': 1,
#   'name:om': 1,
#   'name:or': 1,
#   'name:os': 1,
#   'name:pa': 1,
#   'name:pag': 1,
#   'name:pam': 1,
#   'name:pap': 1,
#   'name:pcd': 1,
#   'name:pdc': 1,
#   'name:pfl': 1,
#   'name:pih': 1,
#   'name:pl': 2,
#   'name:pms': 1,
#   'name:pnb': 1,
#   'name:ps': 1,
#   'name:pt': 4,
#   'name:qu': 2,
#   'name:rm': 1,
#   'name:rn': 1,
#   'name:ro': 2,
#   'name:roa-tara': 1,
#   'name:ru': 20,
#   'name:rue': 1,
#   'name:rw': 1,
#   'name:sa': 1,
#   'name:sah': 1,
#   'name:sc': 1,
#   'name:scn': 1,
#   'name:sco': 1,
#   'name:sd': 1,
#   'name:se': 1,
#   'name:sg': 1,
#   'name:sh': 1,
#   'name:si': 1,
#   'name:simple': 1,
#   'name:sk': 1,
#   'name:sl': 1,
#   'name:sm': 1,
#   'name:sn': 1,
#   'name:so': 1,
#   'name:source': 10,
#   'name:sq': 1,
#   'name:sr': 1,
#   'name:srn': 1,
#   'name:ss': 1,
#   'name:stq': 1,
#   'name:su': 1,
#   'name:sv': 1,
#   'name:sw': 1,
#   'name:szl': 1,
#   'name:ta': 1,
#   'name:te': 1,
#   'name:tet': 1,
#   'name:tg': 1,
#   'name:th': 2,
#   'name:tk': 1,
#   'name:tl': 2,
#   'name:tn': 1,
#   'name:to': 1,
#   'name:tpi': 1,
#   'name:tr': 2,
#   'name:ts': 1,
#   'name:tt': 1,
#   'name:tw': 1,
#   'name:ty': 1,
#   'name:tzl': 1,
#   'name:udm': 1,
#   'name:ug': 1,
#   'name:uk': 7,
#   'name:ur': 1,
#   'name:uz': 1,
#   'name:vec': 1,
#   'name:vep': 1,
#   'name:vi': 1,
#   'name:vls': 1,
#   'name:vo': 1,
#   'name:wa': 1,
#   'name:war': 1,
#   'name:wo': 1,
#   'name:wuu': 1,
#   'name:xal': 1,
#   'name:xh': 1,
#   'name:xmf': 1,
#   'name:yi': 2,
#   'name:yo': 1,
#   'name:za': 1,
#   'name:zea': 1,
#   'name:zh': 3,
#   'name:zh-classical': 1,
#   'name:zh-min-nan': 1,
#   'name:zh-yue': 1,
#   'name:zu': 1,
#   'name_1': 3802,
#   'name_2': 245,
#   'name_3': 27,
#   'name_4': 1,
#   'natural': 10119,
#   'navigationaid': 2,
#   'network': 187,
#   'nist:fips_code': 4,
#   'nist:state_fips': 4,
#   'noexit': 181,
#   'noname': 5,
#   'noref': 67,
#   'note': 517,
#   'note:highway': 2,
#   'note:lanes': 859,
#   'note:name': 158,
#   'note:oneway:flow': 3,
#   'note:operator': 35,
#   'note:ref': 60,
#   'noten': 1,
#   'ntd_id': 8304,
#   'nudism': 2,
#   'odbl': 17,
#   'office': 56,
#   'official_name': 12,
#   'official_name:vi': 1,
#   'old_name': 313,
#   'old_name:vi': 1,
#   'old_railway_operator': 226,
#   'old_ref': 487,
#   'old_ref:1945': 2593,
#   'old_ref:pre_1945': 996,
#   'oneway': 21162,
#   'oneway:bicycle': 4,
#   'oneway:flow': 1104,
#   'opening_hours': 237,
#   'operator': 12082,
#   'organic': 3,
#   'outdoor_seating': 29,
#   'owner': 5,
#   'par': 163,
#   'park_ride': 80,
#   'parking': 666,
#   'parking:lane:right': 1,
#   'passenger': 2,
#   'passing_places': 1,
#   'payment:american_express': 1,
#   'payment:bitcoin': 75,
#   'payment:cash': 2,
#   'payment:coins': 2,
#   'payment:credit_cards': 1,
#   'payment:debits_cards': 1,
#   'payment:discover_card': 1,
#   'payment:litecoin': 5,
#   'payment:mastercard': 1,
#   'payment:paypal': 1,
#   'payment:visa': 1,
#   'phone': 532,
#   'place': 926,
#   'playground': 14,
#   'population': 100,
#   'population:date': 4,
#   'postal_code': 8,
#   'power': 21542,
#   'power_supply': 2,
#   'pram': 2,
#   'proposed': 49,
#   'protect_class': 1,
#   'provided_for:adult': 1,
#   'psv': 1,
#   'public_transport': 10,
#   'public_transport:version': 2,
#   'radar': 1,
#   'railway': 1799,
#   'railway_milepost': 102,
#   'rcn': 326,
#   'rcn_ref': 46,
#   'recycling_type': 3,
#   'ref': 9014,
#   'ref:fips': 1,
#   'ref:nrhp': 1,
#   'ref:store_number': 2,
#   'reg_name': 39,
#   'religion': 580,
#   'residential': 46,
#   'restaurant': 6,
#   'restriction': 224,
#   'roof:colour': 44,
#   'roof:direction': 1,
#   'roof:height': 2,
#   'roof:material': 37,
#   'roof:shape': 139,
#   'route': 331,
#   'route_ref': 8304,
#   'sac_scale': 2,
#   'salt': 119,
#   'scenic': 139,
#   'seamark:beacon_lateral:category': 6,
#   'seamark:buoy_lateral:category': 2,
#   'seamark:buoy_lateral:colour': 2,
#   'seamark:buoy_lateral:system': 1,
#   'seamark:harbour:category': 1,
#   'seamark:mooring:category': 13,
#   'seamark:small_craft_facility:category': 10,
#   'seamark:type': 55,
#   'second_hand': 1,
#   'segregated': 10,
#   'service': 10004,
#   'service:bicycle:chain_tool': 7,
#   'service:bicycle:pump': 3,
#   'service:bicycle:retail': 2,
#   'services': 16,
#   'shelter': 38,
#   'shelter_type': 45,
#   'ship': 40,
#   'shop': 886,
#   'shop_1': 1,
#   'short_name': 84,
#   'short_name:vi': 1,
#   'sidewalk': 6624,
#   'ski': 2,
#   'smoking': 58,
#   'smoothness': 20,
#   'snowmobile': 2,
#   'socket:nema_5_15': 1,
#   'socket:type1': 1,
#   'source': 34692,
#   'source:FIXME': 1,
#   'source:access': 1,
#   'source:addr': 4,
#   'source:date': 8,
#   'source:deep_draft': 32,
#   'source:depth': 34,
#   'source:description': 1,
#   'source:geometry': 90,
#   'source:hgv:national_network': 441,
#   'source:highway': 4,
#   'source:maxspeed': 6497,
#   'source:name': 46,
#   'source:network': 6,
#   'source:noname': 5,
#   'source:oneway': 1,
#   'source:oneway:flow': 139,
#   'source:pkey': 1,
#   'source:population': 4,
#   'source:ref': 1,
#   'source_ref': 1,
#   'sport': 2085,
#   'sport_1': 1,
#   'stars': 3,
#   'start_date': 68,
#   'state': 4,
#   'stile': 1,
#   'stop_name': 1,
#   'structure': 129,
#   'substation': 254,
#   'suite': 1,
#   'supervised': 57,
#   'support': 2,
#   'surface': 11604,
#   'surveillance': 2,
#   'symbol': 17,
#   'takeaway': 26,
#   'tee': 112,
#   'tents': 2,
#   'theatre:genre': 1,
#   'theatre:type': 1,
#   'tiger:CLASSFP': 185,
#   'tiger:CPI': 185,
#   'tiger:FUNCSTAT': 185,
#   'tiger:LSAD': 185,
#   'tiger:MTFCC': 185,
#   'tiger:NAME': 185,
#   'tiger:NAMELSAD': 185,
#   'tiger:PCICBSA': 185,
#   'tiger:PCINECTA': 185,
#   'tiger:PLACEFP': 185,
#   'tiger:PLACENS': 185,
#   'tiger:PLCIDFP': 185,
#   'tiger:STATEFP': 185,
#   'tiger:cfcc': 88176,
#   'tiger:county': 88356,
#   'tiger:name': 1,
#   'tiger:name_base': 81827,
#   'tiger:name_base_1': 5570,
#   'tiger:name_base_2': 518,
#   'tiger:name_base_3': 68,
#   'tiger:name_base_4': 3,
#   'tiger:name_direction_prefix': 52746,
#   'tiger:name_direction_prefix_1': 1770,
#   'tiger:name_direction_prefix_2': 144,
#   'tiger:name_direction_prefix_3': 13,
#   'tiger:name_direction_suffix': 2726,
#   'tiger:name_direction_suffix_1': 143,
#   'tiger:name_direction_suffix_2': 11,
#   'tiger:name_direction_suffix_3': 1,
#   'tiger:name_type': 79221,
#   'tiger:name_type_1': 3647,
#   'tiger:name_type_2': 334,
#   'tiger:name_type_3': 31,
#   'tiger:name_type_4': 2,
#   'tiger:reviewed': 87407,
#   'tiger:separated': 5835,
#   'tiger:source': 6790,
#   'tiger:tlid': 6784,
#   'tiger:upload_uuid': 6784,
#   'tiger:zip_left': 65459,
#   'tiger:zip_left_1': 2408,
#   'tiger:zip_left_2': 614,
#   'tiger:zip_left_3': 242,
#   'tiger:zip_left_4': 85,
#   'tiger:zip_right': 63253,
#   'tiger:zip_right_1': 922,
#   'tiger:zip_right_146': 1,
#   'tiger:zip_right_147': 1,
#   'tiger:zip_right_2': 259,
#   'tiger:zip_right_3': 106,
#   'tiger:zip_right_4': 36,
#   'tiger:zip_right_5': 1,
#   'tiger:zip_rightjun': 1,
#   'timezone': 4,
#   'timezone:note': 1,
#   'to': 7,
#   'toilets': 4,
#   'toilets:disposal': 4,
#   'toilets:wheelchair': 1,
#   'toll': 2200,
#   'toll:bicycle': 19,
#   'toll:hov': 134,
#   'tourism': 669,
#   'tower': 2,
#   'tower:construction': 1,
#   'tower:type': 256,
#   'tracks': 2,
#   'tracktype': 87,
#   'traffic_calming': 102,
#   'traffic_sign': 221,
#   'traffic_signals': 108,
#   'traffic_signals:sound': 1,
#   'trail_visibility': 17,
#   'transformer': 3,
#   'tunnel': 911,
#   'turn:lanes': 130,
#   'turn:lanes:backward': 2,
#   'turn:lanes:forward': 3,
#   'type': 2461,
#   'unsigned_ref': 2565,
#   'url': 18,
#   'usage': 157,
#   'vehicle': 3,
#   'vehicle:lanes': 2,
#   'vending': 4,
#   'verified': 1,
#   'voltage': 884,
#   'water': 531,
#   'waterway': 3920,
#   'website': 815,
#   'wetap:photo': 1,
#   'wetap:status': 6,
#   'wetland': 34,
#   'wheelchair': 154,
#   'width': 33,
#   'wifi': 7,
#   'wikidata': 9,
#   'wikipedia': 322,
#   'wood': 1,
#   'yards': 1,
#   'zip_right': 1,
#   'zoo': 1})

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.cElementTree as ET
import pprint
import re
"""
Your task is to explore the data a bit more.
The first task is a fun one - find out how many unique users
have contributed to the map in this particular area!

The function process_map should return a set of unique user IDs ("uid")
"""

def get_user(element):
	if 'uid' in element.attrib.keys():
		user = element.attrib['uid']

		return user


def process_map(filename):
    users = set()
    user_list = []
    for _, element in ET.iterparse(filename):
	  	if 'uid' in element.attrib.keys():
			user = element.attrib['uid']
  			user_list.append(user)

    users = set(user_list)
    return users


def test():
    osm_file = open("/Users/jpowell/Downloads/data/miami_florida.osm", "r")

    users = process_map(osm_file)
    print len(users)
    pprint.pprint(users)


if __name__ == "__main__":
    test()
# Out:
# 1063
# set(['1',
#      '1007528',
#      '1012362',
#      '1018224',
#      '1020816',
#      '102691',
#      '103107',
#      '103253',
#      '1043009',
#      '1044834',
#      '104519',
#      '104962',
#      '1051550',
#      '105255',
#      '105491',
#      '10557',
#      '1058308',
#      '105839',
#      '1058666',
#      '1068260',
#      '10786',
#      '1087647',
#      '108775',
#      '1090081',
#      '10927',
#      '1093154',
#      '109570',
#      '1096309',
#      '109925',
#      '110263',
#      '110489',
#      '110639',
#      '111159',
#      '11154',
#      '1119200',
#      '113450',
#      '11374',
#      '1149057',
#      '115102',
#      '11547',
#      '115918',
#      '1163648',
#      '1163952',
#      '1171517',
#      '118021',
#      '118048',
#      '119748',
#      '1198074',
#      '1198303',
#      '119881',
#      '120468',
#      '121264',
#      '1214881',
#      '12290',
#      '1233790',
#      '1234774',
#      '123633',
#      '1240770',
#      '1240849',
#      '1241785',
#      '12434',
#      '1243437',
#      '1243643',
#      '1244135',
#      '1244855',
#      '1246157',
#      '1247041',
#      '124815',
#      '1249205',
#      '1251419',
#      '1252272',
#      '125718',
#      '1260280',
#      '128186',
#      '128470',
#      '12919',
#      '129232',
#      '129614',
#      '1298694',
#      '130065',
#      '130472',
#      '1306',
#      '131059',
#      '131200',
#      '1314388',
#      '1318885',
#      '1330847',
#      '1332107',
#      '1339815',
#      '13413',
#      '1342842',
#      '1342868',
#      '134600',
#      '1346164',
#      '135163',
#      '1352459',
#      '135329',
#      '1355899',
#      '137',
#      '1372630',
#      '1373621',
#      '1376118',
#      '1377922',
#      '13832',
#      '1390253',
#      '139562',
#      '13957',
#      '139856',
#      '1403907',
#      '1405281',
#      '140636',
#      '1408522',
#      '1419649',
#      '142262',
#      '1424517',
#      '1425269',
#      '142710',
#      '142776',
#      '1430450',
#      '143134',
#      '1431737',
#      '14390',
#      '145201',
#      '145231',
#      '146680',
#      '147510',
#      '147871',
#      '1480053',
#      '1483073',
#      '14850',
#      '1486839',
#      '1488839',
#      '1494110',
#      '1495201',
#      '1501508',
#      '150272',
#      '150368',
#      '1516612',
#      '152074',
#      '152289',
#      '153305',
#      '1535212',
#      '153651',
#      '153669',
#      '153711',
#      '153904',
#      '155066',
#      '1555726',
#      '1556188',
#      '156349',
#      '15686',
#      '157589',
#      '158204',
#      '15877',
#      '160138',
#      '160651',
#      '160949',
#      '16102',
#      '161269',
#      '161619',
#      '1617449',
#      '162340',
#      '1624486',
#      '16290',
#      '1631775',
#      '163673',
#      '163973',
#      '1651271',
#      '1651798',
#      '1658646',
#      '16591',
#      '1663783',
#      '1665214',
#      '1667251',
#      '167009',
#      '167417',
#      '1676189',
#      '1679',
#      '1679807',
#      '168329',
#      '1687166',
#      '168862',
#      '169004',
#      '1694420',
#      '169474',
#      '1694880',
#      '170106',
#      '170672',
#      '1709203',
#      '1714190',
#      '1714996',
#      '171538',
#      '171818',
#      '171863',
#      '1718866',
#      '1719874',
#      '172061',
#      '1723831',
#      '1724242',
#      '1726004',
#      '1726955',
#      '1728901',
#      '1729779',
#      '1730825',
#      '1731253',
#      '1732064',
#      '1742007',
#      '17427',
#      '1745187',
#      '1748272',
#      '1750007',
#      '1750538',
#      '1750720',
#      '1752954',
#      '1753050',
#      '1755218',
#      '175600',
#      '1764244',
#      '1769658',
#      '177346',
#      '1776782',
#      '177771',
#      '1778799',
#      '1778977',
#      '178186',
#      '1782960',
#      '1783785',
#      '1783862',
#      '17857',
#      '178626',
#      '1788833',
#      '1788849',
#      '1790956',
#      '1791823',
#      '1795433',
#      '1795637',
#      '1796433',
#      '1802220',
#      '1806507',
#      '18069',
#      '1810641',
#      '1810843',
#      '181135',
#      '1811853',
#      '1813115',
#      '1813171',
#      '1814500',
#      '1814732',
#      '181582',
#      '1817650',
#      '1818903',
#      '1819608',
#      '1819820',
#      '1820125',
#      '1821266',
#      '1822346',
#      '1827167',
#      '1829683',
#      '1832883',
#      '1834276',
#      '183438',
#      '1836471',
#      '1841384',
#      '1844441',
#      '1845844',
#      '1848211',
#      '1849867',
#      '1850423',
#      '1850567',
#      '1852',
#      '1852226',
#      '1856433',
#      '1860204',
#      '1860540',
#      '1865164',
#      '1866562',
#      '1869502',
#      '1869583',
#      '1870331',
#      '1872240',
#      '187433',
#      '18744',
#      '1877797',
#      '187839',
#      '187849',
#      '1881064',
#      '1883364',
#      '1883379',
#      '1883445',
#      '1884214',
#      '1884815',
#      '1884889',
#      '1886962',
#      '1888341',
#      '1891908',
#      '1893643',
#      '1898349',
#      '1899869',
#      '1902748',
#      '190389',
#      '1907435',
#      '190869',
#      '1910103',
#      '1910660',
#      '1911765',
#      '191339',
#      '1916438',
#      '1917265',
#      '1919081',
#      '192905',
#      '1930212',
#      '1931772',
#      '193399',
#      '1939272',
#      '1946151',
#      '1950277',
#      '195702',
#      '1959015',
#      '1962477',
#      '1963211',
#      '1963841',
#      '196617',
#      '1967719',
#      '1968361',
#      '1969572',
#      '19735',
#      '1979555',
#      '1979756',
#      '1981230',
#      '198132',
#      '1983513',
#      '198440',
#      '1985907',
#      '1993924',
#      '1994162',
#      '1996396',
#      '2001899',
#      '2003792',
#      '2006475',
#      '200922',
#      '2012449',
#      '201359',
#      '2017758',
#      '202283',
#      '2025754',
#      '2026966',
#      '2027046',
#      '202868',
#      '2031988',
#      '2033130',
#      '2035017',
#      '2041218',
#      '2048918',
#      '2053369',
#      '2055228',
#      '205523',
#      '2058761',
#      '2059301',
#      '2064884',
#      '2065004',
#      '2072931',
#      '2075044',
#      '207581',
#      '2077000',
#      '2077276',
#      '207745',
#      '208170',
#      '2082922',
#      '2082924',
#      '2082949',
#      '2082952',
#      '2082955',
#      '2083139',
#      '2087301',
#      '2089642',
#      '2094226',
#      '2103616',
#      '210834',
#      '211406',
#      '2115749',
#      '2118269',
#      '2118323',
#      '2121112',
#      '2122468',
#      '2126044',
#      '2127730',
#      '2132861',
#      '2135320',
#      '213570',
#      '2135733',
#      '213831',
#      '2138947',
#      '2139707',
#      '2143702',
#      '2147445',
#      '214758',
#      '214969',
#      '2154087',
#      '215691',
#      '2161478',
#      '2167889',
#      '217070',
#      '217127',
#      '2174002',
#      '2177834',
#      '2181933',
#      '2184282',
#      '2186025',
#      '2192620',
#      '2197550',
#      '2210233',
#      '2214041',
#      '2214259',
#      '221878',
#      '2219338',
#      '2219985',
#      '2222901',
#      '2226712',
#      '2226854',
#      '2229444',
#      '2237867',
#      '224440',
#      '2246679',
#      '2250821',
#      '2259836',
#      '2260007',
#      '2261866',
#      '2265178',
#      '2265252',
#      '22701',
#      '22714',
#      '2271895',
#      '228353',
#      '228995',
#      '229013',
#      '22925',
#      '2294399',
#      '229814',
#      '229878',
#      '229916',
#      '230350',
#      '2306749',
#      '2308793',
#      '2309492',
#      '2314573',
#      '2317678',
#      '2318',
#      '232126',
#      '2325238',
#      '2329944',
#      '233248',
#      '23351',
#      '2335615',
#      '2338946',
#      '2344386',
#      '2349071',
#      '236172',
#      '2368151',
#      '2369801',
#      '237223',
#      '2375278',
#      '23762',
#      '2377377',
#      '2380688',
#      '238584',
#      '2397497',
#      '239998',
#      '2400449',
#      '2406049',
#      '2406578',
#      '2407563',
#      '24126',
#      '2418601',
#      '2422391',
#      '2424555',
#      '24247',
#      '2426948',
#      '2427130',
#      '2428402',
#      '2434538',
#      '244113',
#      '2441939',
#      '2443811',
#      '24440',
#      '2449734',
#      '2452155',
#      '245827',
#      '2458458',
#      '2459734',
#      '245990',
#      '2473576',
#      '24748',
#      '2475423',
#      '2483888',
#      '2483892',
#      '2483895',
#      '2483903',
#      '2485772',
#      '2495970',
#      '249634',
#      '2497300',
#      '2499031',
#      '2500700',
#      '2503012',
#      '2504992',
#      '2510485',
#      '2511706',
#      '2512300',
#      '2512306',
#      '2514757',
#      '2514879',
#      '2516309',
#      '2516312',
#      '2516313',
#      '2516316',
#      '251689',
#      '2520751',
#      '2522643',
#      '2527838',
#      '252811',
#      '2528295',
#      '2533093',
#      '2536904',
#      '2537117',
#      '2538098',
#      '2539713',
#      '2542089',
#      '2544247',
#      '2544441',
#      '2546809',
#      '2550539',
#      '255141',
#      '2554698',
#      '2569968',
#      '2572601',
#      '2574196',
#      '258131',
#      '259657',
#      '25996',
#      '260703',
#      '261509',
#      '262151',
#      '262202',
#      '26299',
#      '263430',
#      '2638977',
#      '2644101',
#      '2645613',
#      '2663591',
#      '2673748',
#      '2675037',
#      '2676482',
#      '2679756',
#      '2681348',
#      '2688610',
#      '2699096',
#      '2716442',
#      '2722191',
#      '2748195',
#      '2755647',
#      '2758805',
#      '2766625',
#      '2767111',
#      '2767782',
#      '2768606',
#      '2770728',
#      '2784092',
#      '2786303',
#      '2803613',
#      '2812133',
#      '281267',
#      '2813997',
#      '28145',
#      '2815098',
#      '2820500',
#      '2823295',
#      '2835928',
#      '2844972',
#      '2847906',
#      '2847988',
#      '284945',
#      '28559',
#      '2856365',
#      '2856551',
#      '2858919',
#      '2859402',
#      '2867366',
#      '2867394',
#      '2870598',
#      '28775',
#      '28783',
#      '2879939',
#      '2880275',
#      '2880497',
#      '2881640',
#      '2882957',
#      '28852',
#      '28868',
#      '28923',
#      '2895198',
#      '2903405',
#      '290471',
#      '2905914',
#      '290680',
#      '2906976',
#      '2910104',
#      '2911976',
#      '292007',
#      '292665',
#      '2933274',
#      '2935918',
#      '2942085',
#      '2944689',
#      '294614',
#      '294816',
#      '2953389',
#      '2954900',
#      '2954994',
#      '2959379',
#      '296191',
#      '2972431',
#      '2975800',
#      '2975829',
#      '2975833',
#      '297594',
#      '298201',
#      '2983905',
#      '2984042',
#      '298429',
#      '2985232',
#      '2998632',
#      '3000556',
#      '30035',
#      '300459',
#      '3005567',
#      '3019337',
#      '3021019',
#      '30284',
#      '3028617',
#      '302871',
#      '3030574',
#      '3037363',
#      '3037965',
#      '30383',
#      '30521',
#      '3053656',
#      '305730',
#      '30587',
#      '305985',
#      '3062553',
#      '3065461',
#      '308',
#      '30854',
#      '3090819',
#      '3093601',
#      '3097641',
#      '310589',
#      '3106586',
#      '3109887',
#      '31231',
#      '3128732',
#      '3129309',
#      '313192',
#      '3132700',
#      '3137593',
#      '31385',
#      '3146591',
#      '3146792',
#      '3147171',
#      '3164012',
#      '316694',
#      '316868',
#      '3172721',
#      '3178375',
#      '319792',
#      '3214791',
#      '322785',
#      '3234',
#      '3237469',
#      '323757',
#      '3243496',
#      '3245803',
#      '3247715',
#      '3258663',
#      '3277862',
#      '3282758',
#      '328600',
#      '329453',
#      '32952',
#      '3295563',
#      '3301319',
#      '3304934',
#      '330773',
#      '3307850',
#      '3312693',
#      '3320844',
#      '3321357',
#      '3329241',
#      '3330881',
#      '3338882',
#      '334389',
#      '3346859',
#      '3356200',
#      '3360808',
#      '3362013',
#      '3363664',
#      '336460',
#      '3369384',
#      '337684',
#      '3377543',
#      '3390702',
#      '3391358',
#      '33916',
#      '3394687',
#      '3397088',
#      '339917',
#      '339941',
#      '3406980',
#      '342822',
#      '343700',
#      '344561',
#      '345092',
#      '345754',
#      '346',
#      '346938',
#      '350133',
#      '35018',
#      '350962',
#      '351713',
#      '352368',
#      '35243',
#      '353101',
#      '354170',
#      '355242',
#      '355617',
#      '35585',
#      '3560',
#      '3582',
#      '358273',
#      '360392',
#      '36121',
#      '361348',
#      '362307',
#      '362391',
#      '364',
#      '36443',
#      '36489',
#      '36605',
#      '368215',
#      '368412',
#      '369983',
#      '37137',
#      '373804',
#      '37392',
#      '374955',
#      '379381',
#      '379440',
#      '37987',
#      '380298',
#      '382255',
#      '383288',
#      '38487',
#      '384894',
#      '38588',
#      '386615',
#      '388531',
#      '38952',
#      '390024',
#      '39060',
#      '39330',
#      '394558',
#      '39457',
#      '394697',
#      '39504',
#      '396743',
#      '3980',
#      '398300',
#      '398817',
#      '3990',
#      '401102',
#      '401145',
#      '401490',
#      '402624',
#      '402672',
#      '40397',
#      '4049',
#      '405070',
#      '405293',
#      '4054',
#      '408202',
#      '408776',
#      '409731',
#      '412146',
#      '413047',
#      '414318',
#      '41553',
#      '417785',
#      '417984',
#      '418829',
#      '418930',
#      '419156',
#      '42123',
#      '42191',
#      '42429',
#      '425877',
#      '429761',
#      '430046',
#      '430251',
#      '431056',
#      '434941',
#      '4363',
#      '436419',
#      '437598',
#      '439947',
#      '441065',
#      '44221',
#      '443130',
#      '44659',
#      '446964',
#      '447496',
#      '447903',
#      '449569',
#      '4499',
#      '45027',
#      '451048',
#      '451693',
#      '45243',
#      '45263',
#      '456610',
#      '458834',
#      '46140',
#      '46166',
#      '463963',
#      '46789',
#      '469297',
#      '4697',
#      '472018',
#      '4732',
#      '473471',
#      '474051',
#      '47544',
#      '475877',
#      '477559',
#      '47892',
#      '479256',
#      '479837',
#      '480194',
#      '481116',
#      '481533',
#      '483727',
#      '486556',
#      '487129',
#      '488866',
#      '49031',
#      '492311',
#      '49351',
#      '495739',
#      '496835',
#      '496923',
#      '499783',
#      '5013',
#      '503447',
#      '507640',
#      '508',
#      '51045',
#      '510836',
#      '51324',
#      '515211',
#      '5164',
#      '520239',
#      '521684',
#      '522978',
#      '524500',
#      '525566',
#      '52626',
#      '526849',
#      '527105',
#      '527535',
#      '52797',
#      '5286',
#      '529207',
#      '5294',
#      '529645',
#      '53050',
#      '53073',
#      '531879',
#      '533465',
#      '534135',
#      '534149',
#      '5342',
#      '5359',
#      '5409',
#      '5453',
#      '54626',
#      '54759',
#      '550560',
#      '554234',
#      '557679',
#      '557948',
#      '558778',
#      '55916',
#      '55945',
#      '560392',
#      '564222',
#      '564585',
#      '567034',
#      '567344',
#      '567601',
#      '569208',
#      '570790',
#      '5715',
#      '571501',
#      '571827',
#      '573196',
#      '5748',
#      '575547',
#      '580516',
#      '580542',
#      '581277',
#      '585628',
#      '586214',
#      '588416',
#      '589596',
#      '58971',
#      '590608',
#      '590907',
#      '591544',
#      '592017',
#      '595246',
#      '596047',
#      '599436',
#      '599469',
#      '60110',
#      '601170',
#      '602884',
#      '603532',
#      '605128',
#      '607817',
#      '609937',
#      '612391',
#      '61599',
#      '616152',
#      '617465',
#      '618377',
#      '618879',
#      '620171',
#      '620937',
#      '624928',
#      '625059',
#      '626690',
#      '627111',
#      '630068',
#      '630798',
#      '63107',
#      '632378',
#      '636560',
#      '637742',
#      '64065',
#      '643704',
#      '647831',
#      '650461',
#      '651869',
#      '655370',
#      '660222',
#      '66240',
#      '663559',
#      '663790',
#      '664301',
#      '665599',
#      '665694',
#      '667073',
#      '668349',
#      '669873',
#      '677418',
#      '67862',
#      '680082',
#      '684651',
#      '685704',
#      '68982',
#      '69853',
#      '70',
#      '703517',
#      '706587',
#      '70696',
#      '707052',
#      '7079',
#      '710623',
#      '711265',
#      '714898',
#      '7168',
#      '718617',
#      '7203',
#      '722137',
#      '72235',
#      '725620',
#      '73405',
#      '74705',
#      '757042',
#      '757237',
#      '76002',
#      '775666',
#      '779658',
#      '78656',
#      '7893',
#      '79933',
#      '80046',
#      '804959',
#      '818552',
#      '822818',
#      '82317',
#      '82820',
#      '828956',
#      '833786',
#      '8339',
#      '834399',
#      '837425',
#      '84054',
#      '84263',
#      '84805',
#      '84873',
#      '849096',
#      '86027',
#      '8703',
#      '870861',
#      '8764',
#      '879678',
#      '88164',
#      '88244',
#      '88337',
#      '88347',
#      '88961',
#      '8909',
#      '89098',
#      '894121',
#      '897213',
#      '902646',
#      '912425',
#      '914807',
#      '91490',
#      '91499',
#      '921379',
#      '92274',
#      '92286',
#      '929978',
#      '93788',
#      '939381',
#      '941449',
#      '9437',
#      '94578',
#      '94627',
#      '951623',
#      '95387',
#      '95598',
#      '95842',
#      '959039',
#      '969831',
#      '985060',
#      '987393',
#      '99497',
#      '994975',
#      '996997',
#      '99753',
#      '999995'])

# %%
"""
Your task in this exercise has two steps:

- audit the OSMFILE and change the variable 'mapping' to reflect the changes needed to fix
    the unexpected street types to the appropriate ones in the expected list.
    You have to add mappings only for the actual problems you find in this OSMFILE,
    not a generalized solution, since that may and will depend on the particular area you are auditing.
- write the update_name function, to actually fix the street name.
    The function takes a string with street name as an argument and should return the fixed name
    We have provided a simple test so that you see what exactly is expected
"""
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint


street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
street_direction_re = re.compile(r'^\w+', re.IGNORECASE)

expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road",
            "Trail", "Parkway", "Commons", "Circle", "Crescent", "Highway", "Manor", "Terrace",
            "Trace", "Way", "Causeway", "Point", "State Road"]

expected_direction = ["North", "South", "East", "West", "Northeast", "Northwest", "Southeast", "Southwest"]

# UPDATE THIS VARIABLE
mapping = { "AVE": "Avenue",
            "Ave": "Avenue",
            "Ave.": "Avenue",
            "ave": "Avenue",
            "BLVD": "Boulevard",
            "Blvd": "Boulevard",
            "Blvd.": "Boulevard",
            "Cir": "Circle",
            "Cirlce": "Circle",
            "Cres": "Crescent",
            "Ct": "Court",
            "Dr": "Drive",
            "Druve": "Drive",
            "HWY": "Highway",
            "Hwy": "Highway",
            "Ln": "Lane",
            "Mnr": "Manor",
            "Pkwy": "Parkway",
            "Pl": "Place",
            "Pt": "Point",
            "ST": "Street",
            "st": "Street",
            "St": "Street",
            "Sr": "State Road",
            "street": "Street",
            "St.": "Street",
            "RD": "Road",
            "Rd": "Road",
            "Rd.": "Road",
            "Ter": "Terrace",
            "Trce": "Trace",
            "Trl": "Trail", 
            "NW": "Northwest",
            "Cv": "Cove",
            "Hwy-1": "US Highway 1",
            "Ste": "Suite",
            "Spgs" : ""
            }

mapping_direction = {
            "N": "North",
            "S": "South",
            "E": "East",
            "W": "West",
            "NE": "Northeast",
            "Norhwest": "Northwest",
            "NW": "Northwest",
            "SE": "Southeast",
            "SW": "Southwest",
            "sw": "Southwest",
            "southwest": "Southwest", 
            "St": "Saint",
            "Hwy": "Highway", 
            "royal": "Royal",
            "wellington": "Wellington"
}


def audit_street_type(street_types, street_name):
    m = street_type_re.search(update_name(street_name, mapping))
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def audit_street_direction(street_directions, street_name):
    m = street_direction_re.search(update_name(street_name, mapping_direction))
    if m:
        street_direction = m.group()
        if street_direction not in expected_direction:
            street_directions[street_direction].add(street_name)


def audit_state(state_name, street_name):
    if state_name not in expected_state:
        street_directions[street_direction].add(street_name)

            
def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def is_zip_code(elem):
    return (elem.attrib['k'] == "addr:postcode")


def is_state(elem):
    return (elem.attrib['k'] == "addr:state")


def is_house_no(elem):
    return (elem.attrib['k'] == "addr:housenumber")


def is_city(elem):
    return (elem.attrib['k'] == "addr:city")


def audit_type(osmfile):
    osm_file = osmfile
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])

    return street_types


def audit_direction(osmfile):
    osm_file = osmfile
    street_directions = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_direction(street_directions, tag.attrib['v'])
                if is_zip_code(tag):                  
                    zip_code = re.sub(r"\D", "", tag.attrib['v'])
#                     print zip_code[0:5]
#                 if is_state(tag):
#                     print tag.attrib['v']
#                 if is_city(tag):
#                     print tag.attrib['v']
                if is_house_no(tag):
                    print tag.attrib['v']


  
    return street_directions


def update_name(name, mapping):
    m = street_type_re.search(name)
    if m:
        street_type = m.group()
        if street_type in mapping:
            name = name.replace(street_type, mapping[street_type])

    a = street_direction_re.search(name)
    if a: 
        street_direction = a.group()
        if street_direction in mapping:
            name = name.replace(street_direction, mapping[street_direction])
            
    return name


def test():
    osmfile = open("/Users/jpowell/Downloads/data/miami_florida_sample.osm", "r")
    
#     st_types = audit_type(osmfile)
#     print len(st_types)
#     pprint.pprint(dict(st_types))


    st_directions = audit_direction(osmfile)
    print len(st_directions)
#     pprint.pprint(dict(st_directions))
    
    
#     for st_type, ways in st_types.iteritems():
#         for name in ways:
#             better_name = update_name(name, mapping)
#             print name, "=>", better_name

#     for st_direction, ways in st_directions.iteritems():
#         for name in ways:
#             print name
#             better_name = update_name(name, mapping_direction)
#             print better_name


if __name__ == '__main__':
    test()
# Out:
# 51
# 4725
# 101
# 5525
# 5503
# 3427
# 5506
# 1857
# 16300
# 6130
# 4190
# 300
# 9846
# 16351
# 16367
# 118
# 1500
# 108
# 1800
# 407
# 1020
# 1045
# 218
# 3271
# 2351
# 1601
# 8650
# 921
# 3111
# B1
# 20500
# 9655
# 3421
# 12596
# 1738
# 904
# 3250
# 2704
# 2732
# 2811
# 700
# 4615
# 2746
# 2798
# 2770
# 20283
# 990
# 250
# 9625
# 1600
# 2745
# 2390
# 1400
# 20417
# 1090
# 6530
# 6630
# 6730
# 912
# 932
# 1120
# 6730
# 255
# 1201
# 0
# 10
# 1000
# 1000
# 1002
# 1004
# 1005
# 1006
# 1007
# 1009
# 1010
# 1011
# 1012
# 1013
# 1014
# 1016
# 1017
# 1018
# 102
# 1020
# 1022
# 1023
# 1024
# 1025
# 1027
# 1028
# 103
# 1030
# 1032
# 1033
# 1035
# 1036
# 1037
# 1039
# 1040
# 1040
# 1041
# 1042
# 1043
# 1045
# 1046
# 1047
# 1049
# 1050
# 1050
# 1051
# 1053
# 1054
# 1057
# 1059
# 106
# 1060
# 1062
# 1064
# 1065
# 1067
# 1069
# 925
# 926
# 928
# 929
# 930
# 931
# 932
# 933
# 935
# 936
# 938
# 940
# 941
# 941
# 943
# 945
# 947
# 948
# 949
# 950
# 952
# 953
# 955
# 957
# 958
# 960
# 961
# 962
# 965
# 966
# 968
# 969
# 971
# 972
# 976
# 978
# 980
# 982
# 984
# 988
# 990
# 992
# 995
# 998
# 129
# 153
# 199
# 8750
# 33290 South
# 537, Suite 5
# 40 North
# 1600
# 12551
# 118
# 9975
# 9595
# 2301
# 319
# 101
# 929
# 771
# 2551
# 2491
# 14530
# 3485
# 3900
# 8205
# 10427
# 13465
# 2860
# 14205
# 3238
# 3400
# 14350
# 14345
# 14440
# 3648
# 2250
# 2700
# 2435
# 3533
# 3772
# 3521
# 6361
# 3300
# 6060
# 10300
# 5839
# 5590
# 1155
# 1
# 1121
# 1141
# 6403
# 1120
# 520
# 1490
# 4925
# 5415
# 21351
# 8221
# 11300
# 8841
# 9407
# 14601
# 6503
# 14200
# 425
# 9300
# 10655
# 12105
# 120
# 500
# 199
# 1627
# 6498
# 9008
# 10250
# 18330
# 626
# 855
# 928
# 1343
# 1414
# 205
# 2335
# 2200
# 1677
# 19195
# 2900
# 3750
# 3000
# 1500
# 14838
# 2500
# 1040
# 9020
# 8701
# 6510
# 1532
# 200
# 900
# 536
# 825
# 1109
# 600
# 1541
# 2125
# 1200
# 200
# 3001
# 77
# 425
# 500
# 414
# 4800
# 210
# 5215
# 789
# 5240
# 294
# 1615
# 2309
# 5000
# 675
# 1415
# 6980
# 1701
# 1103
# 151
# 700
# 2800
# 606
# 552
# 1508
# 1499
# 5505
# 200
# 8686
# 2175
# 120
# 6400
# 8401
# 1930
# 4499
# 12477
# 1231
# 15024
# 1501
# 2401
# 530
# 1700
# 386

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.cElementTree as ET
import pprint
import re
import codecs
import json
from collections import defaultdict
"""
Your task is to wrangle the data and transform the shape of the data
into the model we mentioned earlier. The output should be a list of dictionaries
that look like this:

{
"id": "2406124091",
"type: "node",
"visible":"true",
"created": {
          "version":"2",
          "changeset":"17206049",
          "timestamp":"2013-08-03T16:43:42Z",
          "user":"linuxUser16",
          "uid":"1219059"
        },
"pos": [41.9757030, -87.6921867],
"address": {
          "housenumber": "5157",
          "postcode": "60625",
          "street": "North Lincoln Ave"
        },
"amenity": "restaurant",
"cuisine": "mexican",
"name": "La Cabana De Don Luis",
"phone": "1 (773)-271-5176"
}

You have to complete the function 'shape_element'.
We have provided a function that will parse the map file, and call the function with the element
as an argument. You should return a dictionary, containing the shaped data for that element.
We have also provided a way to save the data in a file, so that you could use
mongoimport later on to import the shaped data into MongoDB.

Note that in this exercise we do not use the 'update street name' procedures
you worked on in the previous exercise. If you are using this code in your final
project, you are strongly encouraged to use the code from previous exercise to
update the street names before you save them to JSON.

In particular the following things should be done:
- you should process only 2 types of top level tags: "node" and "way"
- all attributes of "node" and "way" should be turned into regular key/value pairs, except:
    - attributes in the CREATED array should be added under a key "created"
    - attributes for latitude and longitude should be added to a "pos" array,
      for use in geospacial indexing. Make sure the values inside "pos" array are floats
      and not strings.
- if second level tag "k" value contains problematic characters, it should be ignored
- if second level tag "k" value starts with "addr:", it should be added to a dictionary "address"
- if second level tag "k" value does not start with "addr:", but contains ":", you can process it
  same as any other tag.
- if there is a second ":" that separates the type/direction of a street,
  the tag should be ignored, for example:

<tag k="addr:housenumber" v="5158"/>
<tag k="addr:street" v="North Lincoln Avenue"/>
<tag k="addr:street:name" v="Lincoln"/>
<tag k="addr:street:prefix" v="North"/>
<tag k="addr:street:type" v="Avenue"/>
<tag k="amenity" v="pharmacy"/>

  should be turned into:

{...
"address": {
    "housenumber": 5158,
    "street": "North Lincoln Avenue"
}
"amenity": "pharmacy",
...
}

- for "way" specifically:

  <nd ref="305896090"/>
  <nd ref="1719825889"/>

should be turned into
"node_refs": ["305896090", "1719825889"]
"""


lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
street_direction_re = re.compile(r'^\w+', re.IGNORECASE)

CREATED = ["version", "changeset", "timestamp", "user", "uid"]

MAPPING = { "AVE": "Avenue",
            "Ave": "Avenue",
            "Ave.": "Avenue",
            "ave": "Avenue",
            "BLVD": "Boulevard",
            "Blvd": "Boulevard",
            "Blvd.": "Boulevard",
            "Cir": "Circle",
            "Cirlce": "Circle",
            "Cres": "Crescent",
            "Ct": "Court",
            "Dr": "Drive",
            "Druve": "Drive",
            "HWY": "Highway",
            "Hwy": "Highway",
            "Ln": "Lane",
            "Mnr": "Manor",
            "Pkwy": "Parkway",
            "Pl": "Place",
            "Pt": "Point",
            "ST": "Street",
            "st": "Street",
            "St": "Street",
            "Sr": "State Road",
            "street": "Street",
            "St.": "Street",
            "RD": "Road",
            "Rd": "Road",
            "Rd.": "Road",
            "Ter": "Terrace",
            "Trce": "Trace",
            "Trl": "Trail", 
            "NW": "Northwest",
            "Cv": "Cove",
            "Hwy-1": "US Highway 1",
            "Ste": "Suite",
            "Spgs" : ""
            }

MAPPING_DIRECTION = {
            "N": "North",
            "S": "South",
            "E": "East",
            "W": "West",
            "NE": "Northeast",
            "Norhwest": "Northwest",
            "NW": "Northwest",
            "SE": "Southeast",
            "SW": "Southwest",
            "sw": "Southwest",
            "southwest": "Southwest", 
            "St": "Saint",
            "Hwy": "Highway", 
            "royal": "Royal",
            "wellington": "Wellington"
}


def update_name(name, mapping):
    m = street_type_re.search(name)
    if m:
        street_type = m.group()
        if street_type in mapping:
            name = name.replace(street_type, mapping[street_type])

    a = street_direction_re.search(name)
    if a: 
        street_direction = a.group()
        if street_direction in mapping:
            name = name.replace(street_direction, mapping[street_direction])
 
    return name


def shape_element(element):
    node = {"created": {}, "type": 'node', "address": {}, "node_refs": []}
    if element.tag == "node" or element.tag == "way":
        node["type"] = element.tag
        # print element.tag
        # print element.attrib.keys()
        for key in element.attrib.keys():
            if key in CREATED:
                node["created"][key] = element.attrib[key]
            elif key == "lat" or key == "lon":
                node["pos"] = []
                lat = float(element.attrib["lat"])
                lon = float(element.attrib["lon"])
                node["pos"].extend((lat, lon))
            else:
                node[key] = element.attrib[key]

        for child in element:
            if child.tag == "tag":
                if problemchars.search(child.attrib["k"]):
                    continue
                elif child.attrib["k"].startswith("addr:"):
                    addr_attribute = child.attrib["k"].replace("addr:", "")
                    if not lower_colon.search(addr_attribute):
                        if addr_attribute == "full":
                            continue
                        elif addr_attribute == "street":
#                             print addr_attribute
#                             print child.attrib["v"]
#                             print update_name(child.attrib["v"], MAPPING)
                            node["address"][addr_attribute] = update_name(child.attrib["v"], MAPPING)
                            node["address"][addr_attribute] = update_name(child.attrib["v"], MAPPING_DIRECTION)
#                             print node["address"]
                        elif addr_attribute == "city":
                            city = re.sub(r", Florida", "", child.attrib['v'])
                            city = re.sub(r", FL", "", city)
                            node["address"][addr_attribute] = city.title()
                        elif addr_attribute == "state":
                            node["address"][addr_attribute] = "FL"
                        elif addr_attribute == "housenumber":
                            node["address"][addr_attribute] = re.sub(r"\W", "", child.attrib['v'])
                        elif addr_attribute == "postalcode":
                            node["address"][addr_attribute] = re.sub(r"\D", "", child.attrib['v'])
                        else:
                            node["address"][addr_attribute] = child.attrib["v"]
#                             print node
#                     print node["address"]
                else: 
                    node[child.attrib["k"]] = child.attrib["v"]
            elif child.tag == "nd":
                node["node_refs"].append(child.attrib["ref"])
            else:
                print child.tag, child.attrib

        if not bool(node["address"]):
            node.pop("address", None)
        if not bool(node["node_refs"]):
            node.pop("node_refs", None)

#         print node
        return node
    else:
        return None


def process_map(file_in, pretty=False):
    # You do not need to change this file
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data


def test():
    # NOTE: if you are running this code on your computer, with a larger dataset,
    # call the process_map procedure with pretty=False. The pretty=True option adds
    # additional spaces to the output, making it significantly larger.
    osmfile = "/Users/jpowell/Downloads/data/miami_florida.osm"
    data = process_map(osmfile, False)
#     pprint.pprint(data)


if __name__ == "__main__":
    test()

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import xml.etree.ElementTree as ET  # Use cElementTree or lxml if too slow

# OSM_FILE = "osm_file.osm"  # Replace this with your osm file
OSM_FILE = "/Users/jpowell/Downloads/data/miami_florida.osm"
SAMPLE_FILE = "/Users/jpowell/Downloads/data/miami_florida_sample.osm"


def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every 20th top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % 20 == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')
